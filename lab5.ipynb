# %%
import nltk
import pandas as pd
from collections import Counter

# %% [markdown]
# ### Data

# %%
df = pd.read_csv("GrammarandProductReviews.csv")
train_set = df['reviews.text']
reviews = df['reviews.text']

# %%
df.head(3)
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
#
#                                          name  ...   reviews.id  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...          NaN
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
#
#   reviews.numHelpful reviews.rating  \
# 0                0.0              5
# 1                NaN              5
# 2                NaN              5
#
#                                   reviews.sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
# 2   https://www.walmart.com/reviews/product/29775278
#
#                                         reviews.text  reviews.title  \
# 0  i love this album. it's very good. more to the...   Just Awesome
# 1  Good flavor. This review was collected as part...           Good
# 2                                       Good flavor.           Good
#
#    reviews.userCity  reviews.userProvince reviews.username          upc
# 0       Los Angeles                   NaN           Joshua  6.02537E+11
# 1               NaN                   NaN        Dorothy W  73416000391
# 2               NaN                   NaN        Dorothy W  73416000391
#
# [3 rows x 25 columns]

# %% [markdown]
# ### Frecuncy of words

# %%
frec = Counter()
for i in reviews:
    frec.update(w for w in str(i).split())

# %%
frec
# Out:
# Counter({'i': 4958,
#          'love': 12839,
#          'this': 36680,
#          'album.': 38,
#          "it's": 3745,
#          'very': 9955,
#          'good.': 1069,
#          'more': 5734,
#          'to': 61021,
#          'the': 103159,
#          'hip': 7,
#          'hop': 3,
#          'side': 335,
#          'than': 4346,
#          'her': 1028,
#          'current': 107,
#          'pop': 270,
#          'sound..': 2,
#          'SO': 243,
#          'HYPE!': 1,
#          'listen': 100,
#          'everyday': 539,
#          'at': 7401,
#          'gym!': 5,
#          'give': 1222,
#          'it': 46189,
#          '5star': 2,
#          'rating': 78,
#          'all': 9908,
#          'way.': 353,
#          'metaphors': 1,
#          'are': 12939,
#          'just': 7385,
#          'crazy.': 33,
#          'Good': 1494,
#          'flavor.': 98,
#          'This': 28235,
#          'review': 18434,
#          'was': 39948,
#          'collected': 17726,
#          'as': 31759,
#          'part': 18527,
#          'of': 51920,
#          'a': 75635,
#          'promotion.': 17060,
#          'I': 103434,
#          'read': 345,
#          'through': 1116,
#          'reviews': 450,
#          'on': 17319,
#          'here': 353,
#          'before': 1862,
#          'looking': 1888,
#          'in': 27304,
#          'buying': 1068,
#          'one': 7740,
#          'couples': 7,
#          'lubricants,': 1,
#          'and': 85674,
#          'ultimately': 19,
#          'disappointed': 687,
#          'that': 20729,
#          "didn't": 2571,
#          'even': 3665,
#          'live': 733,
#          'up': 5735,
#          'had': 6705,
#          'read.': 14,
#          'For': 639,
#          'starters,': 5,
#          'neither': 31,
#          'my': 44261,
#          'boyfriend': 67,
#          'nor': 127,
#          'could': 2356,
#          'notice': 712,
#          'any': 3638,
#          'sort': 123,
#          'enhanced': 27,
#          'or': 6226,
#          "'captivating'": 2,
#          'sensation.': 12,
#          'What': 666,
#          'we': 3123,
#          'did': 3902,
#          'notice,': 12,
#          'however,': 287,
#          'messy': 242,
#          'consistency': 199,
#          'reminiscent': 11,
#          'liquid-y': 1,
#          'vaseline.': 1,
#          'It': 11918,
#          'difficult': 246,
#          'clean': 5845,
#          'up,': 178,
#          'not': 15340,
#          'pleasant,': 36,
#          'especially': 1285,
#          'since': 1970,
#          'lacked': 15,
#          'sensation': 37,
#          'both': 1128,
#          'been': 5575,
#          'expecting.': 25,
#          "I'm": 3772,
#          'paid': 107,
#          'much': 4410,
#          'for': 34910,
#          'lube': 3,
#          "won't": 647,
#          'use': 13112,
#          'again,': 206,
#          'when': 6438,
#          'their': 1612,
#          'normal': 296,
#          'personal': 137,
#          'lubricant': 3,
#          '1)': 28,
#          'less': 1339,
#          'money': 713,
#          '2)': 31,
#          'mess.': 219,
#          'My': 6815,
#          'husband': 813,
#          'bought': 2920,
#          'gel': 632,
#          'us.': 77,
#          'The': 12795,
#          'caused': 120,
#          'irritation': 62,
#          'felt': 1519,
#          'like': 10729,
#          'burning': 50,
#          'skin.': 1550,
#          "wouldn't": 458,
#          'recommend': 3811,
#          'gel.': 119,
#          'spice': 10,
#          'things': 837,
#          'bedroom': 39,
#          'were': 3325,
#          'highly': 926,
#          'product.': 3469,
#          'We': 2314,
#          'because': 4574,
#          'absolutely': 1154,
#          'ky': 2,
#          'yours': 13,
#          'mine': 212,
#          'thought': 1631,
#          'would': 7783,
#          'have': 23436,
#          'similar': 230,
#          'affect': 49,
#          'but': 17150,
#          'nothing.': 36,
#          'Do': 151,
#          'buy.': 235,
#          'Bought': 527,
#          'earlier': 64,
#          'today': 167,
#          'excited': 691,
#          'check': 131,
#          'out.': 1084,
#          'Based': 16,
#          'product': 14136,
#          'description': 37,
#          'expecting': 254,
#          'something': 1263,
#          'regular': 732,
#          'KY.': 1,
#          'fans': 149,
#          'his': 1117,
#          'hers': 11,
#          'so': 13725,
#          'expected': 312,
#          'left': 1498,
#          'little': 3935,
#          'disappointed.': 350,
#          'try': 2509,
#          'impressed': 434,
#          'all.': 654,
#          'There': 717,
#          'no': 3982,
#          'tingling': 13,
#          'warming.': 5,
#          'us': 474,
#          'sticky.': 85,
#          'used': 6003,
#          'KY': 4,
#          'products': 3118,
#          'past': 505,
#          '(loved': 1,
#          'hers)': 1,
#          'disappointing.': 55,
#          'some': 3465,
#          'extra': 711,
#          'fun.': 151,
#          'werevboth': 1,
#          'extremely': 597,
#          'Especially': 159,
#          'price!': 145,
#          'waste': 309,
#          'your': 5131,
#          'nothing': 737,
#          'sticky': 348,
#          'mess': 518,
#          'from': 6447,
#          'it.': 6015,
#          'Got': 288,
#          'surprise': 100,
#          'there': 2100,
#          'is': 35907,
#          'special': 843,
#          'about': 4591,
#          'save': 293,
#          'get': 5054,
#          'plain': 97,
#          'if': 4322,
#          'you': 11382,
#          'need': 1979,
#          'wish': 919,
#          'return': 275,
#          'refund': 30,
#          'tried': 2730,
#          'with': 19060,
#          'different': 1429,
#          'effect': 170,
#          'change': 778,
#          'first': 4408,
#          'te': 8,
#          'using': 7517,
#          'sure': 1390,
#          'want': 1471,
#          'others...': 3,
#          'Purchased': 119,
#          'thinking': 216,
#          'warming': 25,
#          'same': 1526,
#          'original.': 354,
#          "Don't": 269,
#          'money.': 276,
#          'enhance': 28,
#          'our': 2279,
#          'time': 3919,
#          'bit,': 38,
#          'abslutely': 1,
#          'its': 2156,
#          'almost': 1051,
#          '20!': 5,
#          'after': 5161,
#          'really': 8014,
#          'liking': 55,
#          'n': 100,
#          'variety': 153,
#          'First': 289,
#          'purchase': 1159,
#          'type': 463,
#          'Maybe': 183,
#          'too': 2898,
#          'much.': 360,
#          'Did': 140,
#          'think': 2665,
#          'feeling': 1616,
#          'Left': 65,
#          'sticky!': 7,
#          'Even': 481,
#          'trying': 906,
#          'off.': 312,
#          'wife': 424,
#          'enjoy': 1178,
#          '..we': 1,
#          'feel': 4020,
#          'anything': 976,
#          'enhancement': 3,
#          'such': 931,
#          'his-her': 1,
#          'fianc': 4,
#          'do': 4258,
#          'anything!': 35,
#          'No': 1031,
#          'passion.': 1,
#          'Will': 704,
#          'buy': 3236,
#          'again': 1054,
#          'Very': 1713,
#          'disappointing': 58,
#          'be': 8001,
#          'honest.': 13,
#          'better': 2897,
#          'jelly,': 2,
#          'work': 2367,
#          'well': 3698,
#          'kind': 532,
#          'warm-feeling,': 1,
#          "that's": 540,
#          'guess': 261,
#          "don't": 3829,
#          'know': 2109,
#          "what's": 74,
#          'supposed': 161,
#          'happen!': 6,
#          'Lol': 29,
#          'k-y.': 1,
#          'opinion': 245,
#          'every': 2609,
#          'anything.': 105,
#          'Then': 285,
#          'probably': 477,
#          'Somthing': 1,
#          'wrong.': 101,
#          'noticed': 1546,
#          'clearance': 7,
#          'store': 798,
#          'shop': 71,
#          'frequently': 67,
#          'decided': 484,
#          'try.': 238,
#          'LOVE': 794,
#          'it!': 1624,
#          'went': 978,
#          'back': 2515,
#          'box': 395,
#          'left!': 2,
#          'I,': 34,
#          'others': 524,
#          'mentioned,': 10,
#          'am': 5378,
#          'what': 3315,
#          'other': 4203,
#          'purpose': 88,
#          'Jelly': 1,
#          '(which': 133,
#          'tends': 101,
#          'dry': 2935,
#          'out': 6843,
#          'disappear': 38,
#          'us).': 2,
#          'stays': 293,
#          'awhile': 75,
#          'makes': 2618,
#          'pleasurable': 4,
#          'experience.': 88,
#          'only': 5168,
#          'drawback': 47,
#          'find': 2252,
#          'bit': 1500,
#          'After': 1382,
#          'applying': 340,
#          'hands': 545,
#          "you're": 485,
#          'hand': 454,
#          'agree': 117,
#          'goes': 1101,
#          'long': 2364,
#          'way!': 52,
#          'personally': 142,
#          'careful': 89,
#          'due': 458,
#          'skin': 8191,
#          'surprisingly': 63,
#          'actually': 1090,
#          'seems': 815,
#          'help': 1068,
#          'that.': 298,
#          'NOT': 369,
#          'receive': 232,
#          'sample': 1030,
#          'never': 2372,
#          'have.': 159,
#          'couple': 908,
#          'times': 1189,
#          'recived': 11,
#          'free': 2296,
#          'has': 6467,
#          'good': 8737,
#          'experiance': 1,
#          'warm': 136,
#          'pretty': 1311,
#          'recomend.': 3,
#          'Used': 162,
#          'few': 2165,
#          'bad,': 81,
#          'most': 1450,
#          'Loved': 566,
#          'great': 12302,
#          'feeling.': 153,
#          'enjoyed': 2124,
#          'husband.': 14,
#          '20+': 17,
#          'years': 2207,
#          'marriage,': 1,
#          'can': 5915,
#          'tend': 232,
#          'tired': 133,
#          'boring.': 29,
#          'thing': 1197,
#          'needed': 514,
#          'shake': 21,
#          'bit.': 71,
#          'packaging': 304,
#          'pump': 305,
#          'dispenser': 72,
#          'awesome.': 305,
#          'itself': 284,
#          'does': 3202,
#          'disappoint.': 78,
#          'A': 2226,
#          'provides': 142,
#          'slight': 161,
#          'become': 282,
#          'tacky': 31,
#          'anyway.': 58,
#          'an': 4425,
#          'excellent': 712,
#          'choice': 141,
#          'intimate': 1,
#          'lubricant.': 3,
#          'received': 2888,
#          'review.': 338,
#          'Opinions': 11,
#          '100': 164,
#          'own.': 886,
#          'Awesome': 330,
#          'Product': 169,
#          'couples.': 1,
#          'lot': 1837,
#          'lubricants.It': 1,
#          'easy': 4662,
#          'use.I': 4,
#          'will': 7310,
#          'purchasing': 411,
#          'future.': 211,
#          'review..Opinions': 1,
#          'own!': 82,
#          'Exceptional': 4,
#          'product,': 988,
#          'smooth,': 231,
#          'slimy': 14,
#          'experience': 260,
#          'partners': 1,
#          'should': 906,
#          'share': 105,
#          'least': 521,
#          'once': 878,
#          'lifetime.': 6,
#          'Great': 4875,
#          'way': 2481,
#          'up!': 134,
#          'he': 1193,
#          'loved': 3263,
#          'did.': 239,
#          "Didn't": 112,
#          'entire': 726,
#          'time.': 1337,
#          'product!': 950,
#          'Exactly': 20,
#          'says': 344,
#          'works': 2250,
#          'yes,': 56,
#          'scent': 2544,
#          'best.': 307,
#          'lemon': 282,
#          'frosting': 3,
#          'able': 1127,
#          'enough': 1336,
#          'lotion.': 130,
#          'also,': 48,
#          'natural,': 40,
#          'none': 147,
#          'yucky': 28,
#          'ingredients': 205,
#          'major': 131,
#          'brands': 436,
#          'mineral': 33,
#          'oil,': 29,
#          'petroleum,': 2,
#          'etc.': 317,
#          'completely': 491,
#          'works.': 195,
#          'how': 3888,
#          'sometimes': 344,
#          'opt': 12,
#          'organic': 44,
#          'choices': 34,
#          'good,': 423,
#          'popular': 45,
#          'nastier': 1,
#          'jr': 1,
#          'watkins': 1,
#          'delivers.': 6,
#          'lotion': 643,
#          'softens': 25,
#          'body,': 9,
#          'leaves': 1337,
#          'ungreasy': 1,
#          'smells': 2054,
#          'perfect.': 161,
#          'fiance': 12,
#          'likes': 191,
#          'uses': 359,
#          "he's": 74,
#          'anti-lotion': 1,
#          'regards.': 4,
#          'price': 1562,
#          'right,': 29,
#          'too--get': 1,
#          'Hand-Cream-Lemon-Cream': 1,
#          'refreshing': 142,
#          'fragrance.': 142,
#          'last': 1656,
#          'day.': 886,
#          'soothing': 48,
#          'compliments': 253,
#          'daughters': 103,
#          'granddaughters,': 4,
#          'they': 7952,
#          'me': 5443,
#          'them': 5541,
#          'favorite': 1252,
#          'creams.': 36,
#          'Watkins': 1,
#          'still': 2621,
#          'vanilla': 18,
#          'body': 328,
#          'cream': 1190,
#          'favorite.': 155,
#          'Smells': 250,
#          'cookie.': 8,
#          'Absolutely': 129,
#          'love!!!': 5,
#          'kids': 3182,
#          'You': 1262,
#          'smile': 48,
#          'put': 1985,
#          'on.': 477,
#          'nice': 2418,
#          'desk': 126,
#          'someone': 413,
#          'stole': 16,
#          'two': 1762,
#          'days!': 79,
#          'Broke': 6,
#          'heart': 103,
#          'Nice': 313,
#          'thick,': 149,
#          'feet.': 25,
#          'Not': 1753,
#          'clearing': 15,
#          'complexion': 87,
#          '(been': 1,
#          '2': 1857,
#          'weeks': 1144,
#          'now)': 5,
#          'keep': 2737,
#          'smooth': 1266,
#          'clean.': 929,
#          'Makes': 290,
#          'super': 1151,
#          'where': 997,
#          'ashy': 10,
#          'dont': 341,
#          'follow': 255,
#          'moisturiser': 33,
#          'soon': 331,
#          'im': 143,
#          'done.': 377,
#          'doesnt': 119,
#          'oily': 1439,
#          'tacky.': 7,
#          'radiant': 58,
#          'foundation': 176,
#          'concealer': 106,
#          'make': 3124,
#          'look': 2585,
#          'hydrated.': 121,
#          'face': 2649,
#          'fresh.': 380,
#          '3': 1584,
#          'days': 1280,
#          'acne': 254,
#          'cleared': 72,
#          'right': 1346,
#          'deff': 9,
#          'day': 2305,
#          'now': 2662,
#          'on!': 68,
#          'soap': 339,
#          'considered': 36,
#          "Wal-Mart's": 1,
#          'best': 3088,
#          'kept': 558,
#          'secret.': 6,
#          'stopped': 436,
#          'carrying': 71,
#          'location.': 5,
#          'Was': 358,
#          'delighted': 23,
#          'see': 3327,
#          'online': 198,
#          'ended': 198,
#          'blessing.': 7,
#          'go': 2384,
#          'Wal-Mart': 20,
#          'often': 347,
#          'saving': 84,
#          '(Sorry': 1,
#          'Walmart),': 1,
#          'delivery': 51,
#          'prompt,': 1,
#          'stockpiled': 1,
#          'house.': 576,
#          "WON'T": 4,
#          'anyone': 768,
#          '8': 226,
#          'month': 533,
#          'old': 2777,
#          'baby': 430,
#          'got': 2399,
#          'irritated': 57,
#          'week.': 270,
#          'back.': 307,
#          '1': 1320,
#          'bottle': 1552,
#          'ordered,': 3,
#          'said': 526,
#          'pack': 245,
#          '6.': 25,
#          'convenient': 1005,
#          'bubble': 30,
#          'bath': 111,
#          'wash': 1290,
#          'container,': 37,
#          'means': 141,
#          'twice': 342,
#          'amount...': 1,
#          'son': 815,
#          'loves': 1081,
#          'bubbles': 36,
#          'though': 747,
#          'complaints.': 25,
#          'Well,': 101,
#          "Johnson's": 6,
#          'say': 1706,
#          'know,': 44,
#          'right.': 163,
#          'Ok,': 23,
#          'will.': 32,
#          'baby,': 17,
#          'yes': 94,
#          'But': 1465,
#          "let's": 24,
#          'Chase,': 2,
#          '1.': 76,
#          'Come': 16,
#          'on,': 197,
#          'who': 1554,
#          "doesn't": 2205,
#          "It's": 2828,
#          'hard': 1240,
#          'clean,': 419,
#          'always': 3340,
#          'blessing...': 2,
#          'So,': 165,
#          'Bubble': 3,
#          'Bath': 11,
#          'must': 1271,
#          'house!!!': 6,
#          "aren't": 201,
#          'over': 3212,
#          'top': 771,
#          'fabulous,': 16,
#          'happy.': 94,
#          'ma': 3,
#          'she': 916,
#          'old.': 144,
#          'fragnanaces': 1,
#          'hence': 11,
#          'another': 1315,
#          'one.': 1101,
#          'Lots': 213,
#          'fun': 1169,
#          'bubble!': 1,
#          'addition': 255,
#          'take': 1139,
#          'bath.': 23,
#          'Amazing': 126,
#          'baths.': 2,
#          'bubblebath.': 1,
#          'too.': 873,
#          'sensitive': 846,
#          'option': 116,
#          'break': 458,
#          'small': 1093,
#          'size': 877,
#          'months': 722,
#          'smell': 4083,
#          'wonderful.': 215,
#          'recently': 448,
#          'new': 3832,
#          'may': 706,
#          'shower': 271,
#          'one!': 145,
#          'pleasant': 356,
#          'smell.': 647,
#          'Only': 240,
#          'whole': 1616,
#          'bubbles.': 3,
#          'babies': 111,
#          'mom': 334,
#          'tear': 72,
#          'fragrance': 556,
#          'looks': 1508,
#          'forward': 354,
#          'also': 3702,
#          'wash.': 195,
#          '2-': 2,
#          'in-1': 1,
#          'Really': 441,
#          'liked': 1604,
#          'fresh': 1734,
#          'this.': 661,
#          'throat': 18,
#          'area.': 121,
#          'gone': 304,
#          'generic': 49,
#          'brand,': 66,
#          'expensive.': 92,
#          '(and': 170,
#          'loved)': 3,
#          'several': 997,
#          'until': 847,
#          'changed': 502,
#          'moisturize': 139,
#          'soft.': 474,
#          'Now,': 97,
#          'sits': 36,
#          'absorbed.': 14,
#          'film': 1074,
#          'longer': 939,
#          'Oil': 142,
#          'Olay': 2162,
#          '20': 381,
#          'years.': 836,
#          'worked': 994,
#          'me,': 365,
#          'formula': 1124,
#          'HORRIBLE!': 3,
#          'cannot': 426,
#          'did!': 70,
#          'flowery': 14,
#          'thick.': 49,
#          'light': 1480,
#          'disappointed!': 53,
#          'soft': 2473,
#          'results.': 460,
#          'feels': 1931,
#          'greasy,': 165,
#          'awful': 94,
#          'toned': 26,
#          'wrinkle': 70,
#          'anymore.': 173,
#          'five': 227,
#          'star': 190,
#          'many': 2156,
#          'years...why': 1,
#          'Please': 656,
#          'bring': 833,
#          'formula.': 257,
#          "I've": 3679,
#          'terrific.': 22,
#          'improved': 208,
#          'terrible.': 90,
#          'hydrating': 104,
#          'power': 390,
#          '--': 202,
#          'thinner': 40,
#          'stickier.': 1,
#          'Heaven': 3,
#          'lips': 575,
#          '-': 2238,
#          'tastes': 92,
#          'terrible!': 9,
#          'PLEASE': 199,
#          'dump': 11,
#          'Until': 53,
#          'then,': 34,
#          'shopping': 143,
#          'moisturizer...': 1,
#          'alas': 6,
#          'took': 697,
#          'moisturizer': 1952,
#          'However,': 685,
#          'strong': 853,
#          'greasy': 1069,
#          'applied.': 45,
#          'Unfortunately': 117,
#          'search': 92,
#          'moisturizer.': 471,
#          'Olay,': 41,
#          'better.': 578,
#          'swear': 55,
#          'by': 2584,
#          'daily': 748,
#          'thick': 739,
#          'creamy': 223,
#          'job': 1418,
#          'without': 2307,
#          'being': 1342,
#          'heavy.': 90,
#          'container': 505,
#          'away': 788,
#          'impossible': 77,
#          'apply': 760,
#          'makeup,': 47,
#          '10': 579,
#          'minutes': 438,
#          'after.': 72,
#          'Your': 124,
#          'touch,': 16,
#          'slippery.': 1,
#          'And': 1156,
#          'stronger.': 27,
#          'Please,': 52,
#          'OLAY,': 1,
#          'back!!': 14,
#          "I'll": 500,
#          'else.': 175,
#          'overly': 98,
#          "haven't": 689,
#          'found': 1823,
#          'So': 1694,
#          'hoping': 281,
#          'work.': 463,
#          'affrid': 1,
#          'dry.': 349,
#          'gets': 968,
#          'bad': 949,
#          'dig': 14,
#          'legs': 48,
#          'row': 9,
#          'wearing': 255,
#          'mask.': 76,
#          'unnatural': 5,
#          'under': 829,
#          'coated': 8,
#          'instead': 351,
#          'purchased': 1255,
#          'again.': 1183,
#          'Regenerist': 109,
#          'CVS': 3,
#          'Rite': 2,
#          'Aid.': 1,
#          'around': 1707,
#          'Wal': 9,
#          "Mart's": 1,
#          'store,': 68,
#          'it,': 1314,
#          'slightly': 186,
#          'different.': 123,
#          'cheaper': 209,
#          'makes.': 13,
#          'order': 358,
#          'Walmart': 190,
#          'mother': 287,
#          'vowed': 4,
#          'years...': 9,
#          'started': 1099,
#          'paying': 67,
#          'attention': 113,
#          'skincare,': 2,
#          'gave': 564,
#          'olay': 173,
#          'regenerist': 16,
#          "i've": 62,
#          'ever': 1502,
#          '...': 172,
#          'spent': 99,
#          'exploring': 2,
#          'high-end': 21,
#          'brands)!': 2,
#          'understand': 153,
#          'why': 637,
#          "i'm": 74,
#          'upset': 91,
#          'tampered': 3,
#          'with...': 3,
#          '(the': 73,
#          'strong),': 1,
#          'appears': 117,
#          "they've": 54,
#          'watered': 19,
#          'down,': 85,
#          'mushy': 6,
#          'touch': 296,
#          'point': 225,
#          'during': 705,
#          'day,': 288,
#          'starts': 133,
#          'peeling': 47,
#          'off...': 3,
#          'makeup': 472,
#          'all!': 112,
#          'forced': 48,
#          'line': 969,
#          "we've": 70,
#          'stayed': 201,
#          'lives.': 7,
#          'sad,': 14,
#          'sad.': 24,
#          'BRING': 82,
#          'BACK': 75,
#          'THE': 817,
#          'OLD': 70,
#          'FORMULA!': 7,
#          'While': 351,
#          'leave': 1356,
#          'faces': 19,
#          'nourished,': 7,
#          'makeup.': 108,
#          'full': 785,
#          'crumbles': 1,
#          'brushed': 13,
#          'Would': 595,
#          'night': 985,
#          'cream.': 250,
#          'Just': 933,
#          'moisture': 430,
#          'Thought': 89,
#          'Nutragena': 1,
#          'GreatGreatmefeels': 1,
#          'succulent': 1,
#          'silky': 402,
#          'enriching': 1,
#          'Today': 34,
#          'Felt': 18,
#          'going': 1351,
#          'immediately,': 14,
#          'moisturized': 399,
#          'greasy.': 387,
#          'Although': 279,
#          'fragrance-free': 30,
#          'option,': 9,
#          'fragrances,': 12,
#          'final': 110,
#          'Love': 2856,
#          'result': 124,
#          'days.': 348,
#          'friends.': 173,
#          'wrinkles': 648,
#          'face.': 518,
#          'reducing': 58,
#          'taking': 226,
#          'off': 1649,
#          'amazingly': 77,
#          'well,': 384,
#          'headaches': 5,
#          'made': 2439,
#          'eyes': 560,
#          'water': 939,
#          'daily-Olay': 1,
#          'please': 283,
#          'products.': 807,
#          'having': 1187,
#          'years,': 261,
#          'prefer': 392,
#          'formulation': 52,
#          'hydrate': 64,
#          'thin': 224,
#          'answer': 49,
#          'these': 5748,
#          'questions.': 4,
#          'sounds': 97,
#          'start': 602,
#          'sagging.': 5,
#          'helped': 543,
#          'winter': 352,
#          'months.': 185,
#          'morning': 590,
#          'heavy': 765,
#          'warmer': 16,
#          'weather': 114,
#          'though,': 148,
#          'amazing': 1257,
#          'cleansers': 14,
#          'me...I': 6,
#          'trouble': 125,
#          'bed': 205,
#          'on...a': 1,
#          'micro': 18,
#          'sculping': 1,
#          "can't": 1603,
#          'wait': 770,
#          'tonight!': 1,
#          'One': 692,
#          'lasted': 320,
#          'time,': 344,
#          'becuase': 7,
#          'dislike': 60,
#          ...})

# %% [markdown]
# ### N-grams

# %%
def calc_2gram(data):
    
    n_gram = []
    
    for tmp_data in data:
        tmp_data = str(tmp_data)
        last = ""
        for wn in tmp_data.split():
            if last == "":
                last = wn
                continue
                
            n_gram.append((last, wn))
            last = wn

    return n_gram

def calc_3gram(data):
    
    n_gram = []
    
    for tmp_data in data:
        tmp_data = str(tmp_data)
        last = ""
        p_last = ""
        for wn in tmp_data.split():
            if p_last == "":
                p_last = wn
                continue
            elif last == "":
                last = p_last
                p_last = wn
                continue
                
            n_gram.append((last, p_last, wn))
            last = p_last
            p_last = wn

    return n_gram

# %%
n2_gram = calc_2gram(reviews)
n3_gram = calc_3gram(reviews)

# %%
n2_gram
# Out:
# [('i', 'love'),
#  ('love', 'this'),
#  ('this', 'album.'),
#  ('album.', "it's"),
#  ("it's", 'very'),
#  ('very', 'good.'),
#  ('good.', 'more'),
#  ('more', 'to'),
#  ('to', 'the'),
#  ('the', 'hip'),
#  ('hip', 'hop'),
#  ('hop', 'side'),
#  ('side', 'than'),
#  ('than', 'her'),
#  ('her', 'current'),
#  ('current', 'pop'),
#  ('pop', 'sound..'),
#  ('sound..', 'SO'),
#  ('SO', 'HYPE!'),
#  ('HYPE!', 'i'),
#  ('i', 'listen'),
#  ('listen', 'to'),
#  ('to', 'this'),
#  ('this', 'everyday'),
#  ('everyday', 'at'),
#  ('at', 'the'),
#  ('the', 'gym!'),
#  ('gym!', 'i'),
#  ('i', 'give'),
#  ('give', 'it'),
#  ('it', '5star'),
#  ('5star', 'rating'),
#  ('rating', 'all'),
#  ('all', 'the'),
#  ('the', 'way.'),
#  ('way.', 'her'),
#  ('her', 'metaphors'),
#  ('metaphors', 'are'),
#  ('are', 'just'),
#  ('just', 'crazy.'),
#  ('Good', 'flavor.'),
#  ('flavor.', 'This'),
#  ('This', 'review'),
#  ('review', 'was'),
#  ('was', 'collected'),
#  ('collected', 'as'),
#  ('as', 'part'),
#  ('part', 'of'),
#  ('of', 'a'),
#  ('a', 'promotion.'),
#  ('Good', 'flavor.'),
#  ('I', 'read'),
#  ('read', 'through'),
#  ('through', 'the'),
#  ('the', 'reviews'),
#  ('reviews', 'on'),
#  ('on', 'here'),
#  ('here', 'before'),
#  ('before', 'looking'),
#  ('looking', 'in'),
#  ('in', 'to'),
#  ('to', 'buying'),
#  ('buying', 'one'),
#  ('one', 'of'),
#  ('of', 'the'),
#  ('the', 'couples'),
#  ('couples', 'lubricants,'),
#  ('lubricants,', 'and'),
#  ('and', 'was'),
#  ('was', 'ultimately'),
#  ('ultimately', 'disappointed'),
#  ('disappointed', 'that'),
#  ('that', 'it'),
#  ('it', "didn't"),
#  ("didn't", 'even'),
#  ('even', 'live'),
#  ('live', 'up'),
#  ('up', 'to'),
#  ('to', 'the'),
#  ('the', 'reviews'),
#  ('reviews', 'I'),
#  ('I', 'had'),
#  ('had', 'read.'),
#  ('read.', 'For'),
#  ('For', 'starters,'),
#  ('starters,', 'neither'),
#  ('neither', 'my'),
#  ('my', 'boyfriend'),
#  ('boyfriend', 'nor'),
#  ('nor', 'I'),
#  ('I', 'could'),
#  ('could', 'notice'),
#  ('notice', 'any'),
#  ('any', 'sort'),
#  ('sort', 'of'),
#  ('of', 'enhanced'),
#  ('enhanced', 'or'),
#  ('or', "'captivating'"),
#  ("'captivating'", 'sensation.'),
#  ('sensation.', 'What'),
#  ('What', 'we'),
#  ('we', 'did'),
#  ('did', 'notice,'),
#  ('notice,', 'however,'),
#  ('however,', 'was'),
#  ('was', 'the'),
#  ('the', 'messy'),
#  ('messy', 'consistency'),
#  ('consistency', 'that'),
#  ('that', 'was'),
#  ('was', 'reminiscent'),
#  ('reminiscent', 'of'),
#  ('of', 'a'),
#  ('a', 'more'),
#  ('more', 'liquid-y'),
#  ('liquid-y', 'vaseline.'),
#  ('vaseline.', 'It'),
#  ('It', 'was'),
#  ('was', 'difficult'),
#  ('difficult', 'to'),
#  ('to', 'clean'),
#  ('clean', 'up,'),
#  ('up,', 'and'),
#  ('and', 'was'),
#  ('was', 'not'),
#  ('not', 'a'),
#  ('a', 'pleasant,'),
#  ('pleasant,', 'especially'),
#  ('especially', 'since'),
#  ('since', 'it'),
#  ('it', 'lacked'),
#  ('lacked', 'the'),
#  ('the', "'captivating'"),
#  ("'captivating'", 'sensation'),
#  ('sensation', 'we'),
#  ('we', 'had'),
#  ('had', 'both'),
#  ('both', 'been'),
#  ('been', 'expecting.'),
#  ('expecting.', "I'm"),
#  ("I'm", 'disappointed'),
#  ('disappointed', 'that'),
#  ('that', 'I'),
#  ('I', 'paid'),
#  ('paid', 'as'),
#  ('as', 'much'),
#  ('much', 'as'),
#  ('as', 'I'),
#  ('I', 'did'),
#  ('did', 'for'),
#  ('for', 'a'),
#  ('a', 'lube'),
#  ('lube', 'that'),
#  ('that', 'I'),
#  ('I', "won't"),
#  ("won't", 'use'),
#  ('use', 'again,'),
#  ('again,', 'when'),
#  ('when', 'I'),
#  ('I', 'could'),
#  ('could', 'just'),
#  ('just', 'use'),
#  ('use', 'their'),
#  ('their', 'normal'),
#  ('normal', 'personal'),
#  ('personal', 'lubricant'),
#  ('lubricant', 'for'),
#  ('for', '1)'),
#  ('1)', 'less'),
#  ('less', 'money'),
#  ('money', 'and'),
#  ('and', '2)'),
#  ('2)', 'less'),
#  ('less', 'mess.'),
#  ('My', 'husband'),
#  ('husband', 'bought'),
#  ('bought', 'this'),
#  ('this', 'gel'),
#  ('gel', 'for'),
#  ('for', 'us.'),
#  ('us.', 'The'),
#  ('The', 'gel'),
#  ('gel', 'caused'),
#  ('caused', 'irritation'),
#  ('irritation', 'and'),
#  ('and', 'it'),
#  ('it', 'felt'),
#  ('felt', 'like'),
#  ('like', 'it'),
#  ('it', 'was'),
#  ('was', 'burning'),
#  ('burning', 'my'),
#  ('my', 'skin.'),
#  ('skin.', 'I'),
#  ('I', "wouldn't"),
#  ("wouldn't", 'recommend'),
#  ('recommend', 'this'),
#  ('this', 'gel.'),
#  ('My', 'boyfriend'),
#  ('boyfriend', 'and'),
#  ('and', 'I'),
#  ('I', 'bought'),
#  ('bought', 'this'),
#  ('this', 'to'),
#  ('to', 'spice'),
#  ('spice', 'things'),
#  ('things', 'up'),
#  ('up', 'in'),
#  ('in', 'the'),
#  ('the', 'bedroom'),
#  ('bedroom', 'and'),
#  ('and', 'we'),
#  ('we', 'were'),
#  ('were', 'both'),
#  ('both', 'highly'),
#  ('highly', 'disappointed'),
#  ('disappointed', 'in'),
#  ('in', 'this'),
#  ('this', 'product.'),
#  ('product.', 'We'),
#  ('We', 'bought'),
#  ('bought', 'this'),
#  ('this', 'one'),
#  ('one', 'because'),
#  ('because', 'we'),
#  ('we', 'absolutely'),
#  ('absolutely', 'love'),
#  ('love', 'the'),
#  ('the', 'ky'),
#  ('ky', 'yours'),
#  ('yours', 'and'),
#  ('and', 'mine'),
#  ('mine', 'and'),
#  ('and', 'we'),
#  ('we', 'thought'),
#  ('thought', 'this'),
#  ('this', 'would'),
#  ('would', 'have'),
#  ('have', 'a'),
#  ('a', 'similar'),
#  ('similar', 'affect'),
#  ('affect', 'but'),
#  ('but', 'it'),
#  ('it', 'did'),
#  ('did', 'absolutely'),
#  ('absolutely', 'nothing.'),
#  ('nothing.', 'Do'),
#  ('Do', 'not'),
#  ('not', 'buy.'),
#  ('Bought', 'this'),
#  ('this', 'earlier'),
#  ('earlier', 'today'),
#  ('today', 'and'),
#  ('and', 'was'),
#  ('was', 'excited'),
#  ('excited', 'to'),
#  ('to', 'check'),
#  ('check', 'it'),
#  ('it', 'out.'),
#  ('out.', 'Based'),
#  ('Based', 'on'),
#  ('on', 'the'),
#  ('the', 'product'),
#  ('product', 'description'),
#  ('description', 'I'),
#  ('I', 'was'),
#  ('was', 'expecting'),
#  ('expecting', 'something'),
#  ('something', 'but'),
#  ('but', 'it'),
#  ('it', 'was'),
#  ('was', 'just'),
#  ('just', 'like'),
#  ('like', 'the'),
#  ('the', 'regular'),
#  ('regular', 'KY.'),
#  ('KY.', 'We'),
#  ('We', 'are'),
#  ('are', 'fans'),
#  ('fans', 'of'),
#  ('of', 'the'),
#  ('the', 'his'),
#  ('his', 'and'),
#  ('and', 'hers'),
#  ('hers', 'so'),
#  ('so', 'we'),
#  ('we', 'just'),
#  ('just', 'expected'),
#  ('expected', 'more'),
#  ('more', 'and'),
#  ('and', 'were'),
#  ('were', 'left'),
#  ('left', 'a'),
#  ('a', 'little'),
#  ('little', 'disappointed.'),
#  ('I', 'bought'),
#  ('bought', 'this'),
#  ('this', 'product'),
#  ('product', 'for'),
#  ('for', 'my'),
#  ('my', 'husband'),
#  ('husband', 'and'),
#  ('and', 'I'),
#  ('I', 'to'),
#  ('to', 'try'),
#  ('try', 'and'),
#  ('and', 'we'),
#  ('we', 'were'),
#  ('were', 'not'),
#  ('not', 'impressed'),
#  ('impressed', 'at'),
#  ('at', 'all.'),
#  ('all.', 'There'),
#  ('There', 'was'),
#  ('was', 'no'),
#  ('no', 'tingling'),
#  ('tingling', 'or'),
#  ('or', 'warming.'),
#  ('warming.', 'It'),
#  ('It', 'left'),
#  ('left', 'us'),
#  ('us', 'both'),
#  ('both', 'very'),
#  ('very', 'sticky.'),
#  ('sticky.', 'I'),
#  ('I', 'have'),
#  ('have', 'used'),
#  ('used', 'KY'),
#  ('KY', 'products'),
#  ('products', 'in'),
#  ('in', 'the'),
#  ('the', 'past'),
#  ('past', '(loved'),
#  ('(loved', 'KY'),
#  ('KY', 'his'),
#  ('his', 'and'),
#  ('and', 'hers)'),
#  ('hers)', 'but'),
#  ('but', 'this'),
#  ('this', 'one'),
#  ('one', 'was'),
#  ('was', 'disappointing.'),
#  ('My', 'husband'),
#  ('husband', 'and'),
#  ('and', 'I'),
#  ('I', 'bought'),
#  ('bought', 'this'),
#  ('this', 'for'),
#  ('for', 'some'),
#  ('some', 'extra'),
#  ('extra', 'fun.'),
#  ('fun.', 'We'),
#  ('We', 'werevboth'),
#  ('werevboth', 'extremely'),
#  ('extremely', 'disappointed.'),
#  ('disappointed.', 'Especially'),
#  ('Especially', 'for'),
#  ('for', 'the'),
#  ('the', 'price!'),
#  ('price!', 'Do'),
#  ('Do', 'not'),
#  ('not', 'waste'),
#  ('waste', 'your'),
#  ('your', 'money'),
#  ('money', 'on'),
#  ('on', 'this'),
#  ('this', 'product.'),
#  ('product.', 'We'),
#  ('We', 'felt'),
#  ('felt', 'nothing'),
#  ('nothing', 'but'),
#  ('but', 'a'),
#  ('a', 'sticky'),
#  ('sticky', 'mess'),
#  ('mess', 'from'),
#  ('from', 'it.'),
#  ('Got', 'as'),
#  ('as', 'a'),
#  ('a', 'surprise'),
#  ('surprise', 'for'),
#  ('for', 'my'),
#  ('my', 'husband'),
#  ('husband', 'there'),
#  ('there', 'is'),
#  ('is', 'nothing'),
#  ('nothing', 'special'),
#  ('special', 'about'),
#  ('about', 'it'),
#  ('it', 'just'),
#  ('just', 'a'),
#  ('a', 'lube'),
#  ('lube', 'save'),
#  ('save', 'the'),
#  ('the', 'money'),
#  ('money', 'and'),
#  ('and', 'get'),
#  ('get', 'plain'),
#  ('plain', 'KY'),
#  ('KY', 'if'),
#  ('if', 'you'),
#  ('you', 'just'),
#  ('just', 'need'),
#  ('need', 'a'),
#  ('a', 'lube'),
#  ('lube', 'wish'),
#  ('wish', 'I'),
#  ('I', 'could'),
#  ('could', 'return'),
#  ('return', 'it'),
#  ('it', 'for'),
#  ('for', 'a'),
#  ('a', 'refund'),
#  ('tried', 'it'),
#  ('it', 'with'),
#  ('with', 'my'),
#  ('my', 'husband'),
#  ('husband', 'and'),
#  ('and', 'felt'),
#  ('felt', 'no'),
#  ('no', 'different'),
#  ('different', 'there'),
#  ('there', 'was'),
#  ('was', 'no'),
#  ('no', 'effect'),
#  ('effect', 'no'),
#  ('no', 'change'),
#  ('change', 'first'),
#  ('first', 'te'),
#  ('te', 'using'),
#  ('using', 'ky'),
#  ('ky', 'gel'),
#  ('gel', 'not'),
#  ('not', 'sure'),
#  ('sure', 'if'),
#  ('if', 'i'),
#  ('i', 'want'),
#  ('want', 'to'),
#  ('to', 'try'),
#  ('try', 'any'),
#  ('any', 'others...'),
#  ('Purchased', 'this'),
#  ('this', 'thinking'),
#  ('thinking', 'it'),
#  ('it', 'would'),
#  ('would', 'have'),
#  ('have', 'some'),
#  ('some', 'sort'),
#  ('sort', 'of'),
#  ('of', 'warming'),
#  ('warming', 'effect'),
#  ('effect', 'but'),
#  ('but', "it's"),
#  ("it's", 'the'),
#  ('the', 'same'),
#  ('same', 'as'),
#  ('as', 'the'),
#  ('the', 'original.'),
#  ('original.', "Don't"),
#  ("Don't", 'waste'),
#  ('waste', 'your'),
#  ('your', 'money.'),
#  ('Bought', 'this'),
#  ('this', 'to'),
#  ('to', 'enhance'),
#  ('enhance', 'our'),
#  ('our', 'time'),
#  ('time', 'a'),
#  ('a', 'bit,'),
#  ('bit,', 'did'),
#  ('did', 'abslutely'),
#  ('abslutely', 'nothing'),
#  ('nothing', 'very'),
#  ('very', 'disappointed'),
#  ('disappointed', 'especially'),
#  ('especially', 'because'),
#  ('because', 'its'),
#  ('its', 'almost'),
#  ('almost', '20!'),
#  ('I', 'bought'),
#  ('bought', 'this'),
#  ('this', 'after'),
#  ('after', 'really'),
#  ('really', 'liking'),
#  ('liking', 'the'),
#  ('the', 'his'),
#  ('his', 'n'),
#  ('n', 'hers'),
#  ('hers', 'variety'),
#  ('variety', 'but'),
#  ('but', 'this'),
#  ('this', 'is'),
#  ('is', 'nothing'),
#  ('nothing', 'like'),
#  ('like', 'that'),
#  ('that', 'very'),
#  ('very', 'disappointed'),
#  ('disappointed', 'with'),
#  ('with', 'this'),
#  ('this', 'product.'),
#  ('First', 'time'),
#  ('time', 'purchase'),
#  ('purchase', 'of'),
#  ('of', 'this'),
#  ('this', 'type'),
#  ('type', 'of'),
#  ('of', 'product.'),
#  ('product.', 'Maybe'),
#  ('Maybe', 'I'),
#  ('I', 'expected'),
#  ('expected', 'too'),
#  ('too', 'much.'),
#  ('much.', 'Did'),
#  ('Did', 'not'),
#  ('not', 'think'),
#  ('think', 'there'),
#  ('there', 'was'),
#  ('was', 'any'),
#  ('any', 'warming'),
#  ('warming', 'feeling'),
#  ('feeling', 'at'),
#  ('at', 'all.'),
#  ('all.', 'Left'),
#  ('Left', 'us'),
#  ('us', 'sticky!'),
#  ('sticky!', 'Even'),
#  ('Even', 'after'),
#  ('after', 'trying'),
#  ('trying', 'to'),
#  ('to', 'was'),
#  ('was', 'it'),
#  ('it', 'off.'),
#  ('I', 'bought'),
#  ('bought', 'this'),
#  ('this', 'and'),
#  ('and', 'tried'),
#  ('tried', 'this'),
#  ('this', 'with'),
#  ('with', 'my'),
#  ('my', 'wife'),
#  ('wife', 'but'),
#  ('but', 'we'),
#  ('we', 'did'),
#  ('did', 'not'),
#  ('not', 'enjoy'),
#  ('enjoy', 'it'),
#  ('it', '..we'),
#  ('..we', 'did'),
#  ('did', 'not'),
#  ('not', 'feel'),
#  ('feel', 'anything'),
#  ('anything', 'enhancement'),
#  ('enhancement', 'with'),
#  ('with', 'this'),
#  ('this', 'product'),
#  ('product', 'at'),
#  ('at', 'all'),
#  ('all', 'such'),
#  ('such', 'as'),
#  ('as', 'the'),
#  ('the', 'his-her'),
#  ('his-her', 'product.'),
#  ('I', 'bought'),
#  ('bought', 'this'),
#  ('this', 'product'),
#  ('product', 'to'),
#  ('to', 'spice'),
#  ('spice', 'things'),
#  ('things', 'up'),
#  ('up', 'with'),
#  ('with', 'my'),
#  ('my', 'fianc'),
#  ('fianc', 'and'),
#  ('and', 'it'),
#  ('it', "didn't"),
#  ("didn't", 'do'),
#  ('do', 'anything!'),
#  ('anything!', 'No'),
#  ('No', 'passion.'),
#  ('passion.', 'Will'),
#  ('Will', 'not'),
#  ('not', 'buy'),
#  ('buy', 'again'),
#  ('I', 'bought'),
#  ('bought', 'this'),
#  ('this', 'to'),
#  ('to', 'try'),
#  ('try', 'to'),
#  ('to', 'spice'),
#  ('spice', 'things'),
#  ('things', 'up,'),
#  ('up,', 'but'),
#  ('but', 'I'),
#  ('I', 'felt'),
#  ('felt', 'nothing.'),
#  ('nothing.', 'Very'),
#  ('Very', 'disappointing'),
#  ('disappointing', 'to'),
#  ('to', 'be'),
#  ('be', 'honest.'),
#  ('I', 'bought'),
#  ('bought', 'this'),
#  ('this', 'because'),
#  ('because', 'it'),
#  ('it', 'had'),
#  ('had', 'better'),
#  ('better', 'reviews'),
#  ('reviews', 'than'),
#  ('than', 'the'),
#  ('the', 'his'),
#  ('his', 'and'),
#  ('and', 'hers'),
#  ('hers', 'jelly,'),
#  ('jelly,', 'but'),
#  ('but', 'I'),
#  ('I', 'feel'),
#  ('feel', 'like'),
#  ('like', 'it'),
#  ('it', "didn't"),
#  ("didn't", 'work'),
#  ('work', 'that'),
#  ('that', 'well'),
#  ('well', 'for'),
#  ('for', 'us.'),
#  ('us.', 'It'),
#  ('It', 'was'),
#  ('was', 'kind'),
#  ('kind', 'of'),
#  ('of', 'warm-feeling,'),
#  ('warm-feeling,', 'but'),
#  ('but', "that's"),
#  ("that's", 'about'),
#  ('about', 'it.'),
#  ('it.', 'I'),
#  ('I', 'guess'),
#  ('guess', 'I'),
#  ('I', "don't"),
#  ("don't", 'know'),
#  ('know', "what's"),
#  ("what's", 'supposed'),
#  ('supposed', 'to'),
#  ('to', 'happen!'),
#  ('happen!', 'Lol'),
#  ('It', 'was'),
#  ('was', 'my'),
#  ('my', 'first'),
#  ('first', 'time'),
#  ('time', 'using'),
#  ('using', 'k-y.'),
#  ('k-y.', 'It'),
#  ('It', "didn't"),
#  ("didn't", 'do'),
#  ('do', 'anything'),
#  ('anything', 'in'),
#  ('in', 'my'),
#  ('my', 'opinion'),
#  ('opinion', 'it'),
#  ('it', 'felt'),
#  ('felt', 'like'),
#  ('like', 'every'),
#  ('every', 'time'),
#  ('time', 'we'),
#  ('we', 'did'),
#  ('did', 'anything.'),
#  ('anything.', 'Then'),
#  ('Then', 'again'),
#  ('again', 'was'),
#  ('was', 'my'),
#  ('my', 'first'),
#  ('first', 'time'),
#  ('time', 'so'),
#  ('so', 'probably'),
#  ('probably', 'did'),
#  ('did', 'Somthing'),
#  ('Somthing', 'wrong.'),
#  ('I', 'noticed'),
#  ('noticed', 'this'),
#  ('this', 'product'),
#  ('product', 'on'),
#  ('on', 'clearance'),
#  ('clearance', 'at'),
#  ('at', 'a'),
#  ('a', 'store'),
#  ('store', 'I'),
#  ('I', 'shop'),
#  ('shop', 'frequently'),
#  ('frequently', 'and'),
#  ('and', 'decided'),
#  ('decided', 'to'),
#  ('to', 'give'),
#  ('give', 'it'),
#  ('it', 'a'),
#  ('a', 'try.'),
#  ('try.', 'My'),
#  ('My', 'husband'),
#  ('husband', 'and'),
#  ('and', 'I'),
#  ('I', 'LOVE'),
#  ('LOVE', 'it!'),
#  ('it!', 'We'),
#  ('We', 'went'),
#  ('went', 'back'),
#  ('back', 'and'),
#  ('and', 'bought'),
#  ('bought', 'every'),
#  ('every', 'box'),
#  ('box', 'left!'),
#  ('left!', 'I,'),
#  ('I,', 'like'),
#  ('like', 'others'),
#  ('others', 'have'),
#  ('have', 'mentioned,'),
#  ('mentioned,', 'am'),
#  ('am', 'not'),
#  ('not', 'sure'),
#  ('sure', 'what'),
#  ('what', 'it'),
#  ('it', 'is'),
#  ('is', 'supposed'),
#  ('supposed', 'to'),
#  ('to', 'do'),
#  ('do', 'other'),
#  ('other', 'than'),
#  ('than', 'be'),
#  ('be', 'a'),
#  ('a', 'lubricant'),
#  ('lubricant', 'but'),
#  ('but', 'for'),
#  ('for', 'that'),
#  ('that', 'purpose'),
#  ('purpose', 'we'),
#  ('we', 'like'),
#  ('like', 'it'),
#  ('it', 'much'),
#  ('much', 'better'),
#  ('better', 'than'),
#  ('than', 'regular'),
#  ('regular', 'KY'),
#  ('KY', 'Jelly'),
#  ('Jelly', '(which'),
#  ('(which', 'tends'),
#  ('tends', 'to'),
#  ('to', 'dry'),
#  ('dry', 'out'),
#  ('out', 'and'),
#  ('and', 'disappear'),
#  ('disappear', 'for'),
#  ('for', 'us).'),
#  ('us).', 'This'),
#  ('This', 'product'),
#  ('product', 'stays'),
#  ('stays', 'on'),
#  ('on', 'for'),
#  ('for', 'awhile'),
#  ('awhile', 'and'),
#  ('and', 'makes'),
#  ('makes', 'for'),
#  ('for', 'a'),
#  ('a', 'very'),
#  ('very', 'pleasurable'),
#  ('pleasurable', 'experience.'),
#  ('experience.', 'The'),
#  ('The', 'only'),
#  ('only', 'drawback'),
#  ('drawback', 'is'),
#  ('is', 'that'),
#  ('that', 'we'),
#  ('we', 'find'),
#  ('find', 'it'),
#  ('it', 'to'),
#  ('to', 'be'),
#  ('be', 'a'),
#  ('a', 'bit'),
#  ('bit', 'sticky.'),
#  ('sticky.', 'After'),
#  ('After', 'applying'),
#  ('applying', 'it'),
#  ('it', 'with'),
#  ('with', 'your'),
#  ('your', 'hands'),
#  ('hands', "you're"),
#  ("you're", 'left'),
#  ('left', 'with'),
#  ('with', 'a'),
#  ('a', 'sticky'),
#  ('sticky', 'hand'),
#  ('hand', 'and'),
#  ('and', 'I'),
#  ('I', 'agree'),
#  ('agree', 'a'),
#  ('a', 'little'),
#  ('little', 'goes'),
#  ('goes', 'a'),
#  ('a', 'long'),
#  ('long', 'way!'),
#  ('way!', 'I'),
#  ('I', 'personally'),
#  ('personally', 'have'),
#  ('have', 'to'),
#  ('to', 'be'),
#  ('be', 'very'),
#  ('very', 'careful'),
#  ('careful', 'with'),
#  ('with', 'all'),
#  ('all', 'products'),
#  ('products', 'due'),
#  ('due', 'to'),
#  ('to', 'skin'),
#  ('skin', 'irritation'),
#  ('irritation', 'and'),
#  ('and', 'surprisingly'),
#  ('surprisingly', 'this'),
#  ('this', 'actually'),
#  ('actually', 'seems'),
#  ('seems', 'to'),
#  ('to', 'help'),
#  ('help', 'that.'),
#  ('that.', 'I'),
#  ('I', 'did'),
#  ('did', 'NOT'),
#  ('NOT', 'receive'),
#  ('receive', 'a'),
#  ('a', 'sample'),
#  ('sample', 'and'),
#  ('and', 'never'),
#  ('never', 'have.'),
#  ('I', 'used'),
#  ('used', 'this'),
#  ('this', 'product'),
#  ('product', 'a'),
#  ('a', 'couple'),
#  ('couple', 'of'),
#  ('of', 'times'),
#  ('times', 'since'),
#  ('since', 'i'),
#  ('i', 'recived'),
#  ('recived', 'it'),
#  ('it', 'free'),
#  ('free', 'to'),
#  ('to', 'try'),
#  ('try', 'and'),
#  ('and', 'it'),
#  ('it', 'has'),
#  ('has', 'been'),
#  ('been', 'a'),
#  ('a', 'good'),
#  ('good', 'experiance'),
#  ('experiance', 'it'),
#  ('it', 'feel'),
#  ('feel', 'warm'),
#  ('warm', 'so'),
#  ('so', 'its'),
#  ('its', 'a'),
#  ('a', 'pretty'),
#  ('pretty', 'good'),
#  ('good', 'sensation'),
#  ('sensation', 'so'),
#  ('so', 'i'),
#  ('i', 'recomend.'),
#  ('Used', 'a'),
#  ('a', 'few'),
#  ('few', 'times'),
#  ('times', 'stays'),
#  ('stays', 'a'),
#  ('a', 'bit'),
#  ('bit', 'sticky'),
#  ('sticky', 'but'),
#  ('but', 'not'),
#  ('not', 'too'),
#  ('too', 'bad,'),
#  ('bad,', 'better'),
#  ('better', 'than'),
#  ('than', 'most'),
#  ('most', 'products'),
#  ('Loved', 'This'),
#  ('This', 'review'),
#  ('review', 'was'),
#  ('was', 'collected'),
#  ('collected', 'as'),
#  ('as', 'part'),
#  ('part', 'of'),
#  ('of', 'a'),
#  ('a', 'promotion.'),
#  ('This', 'is'),
#  ('is', 'a'),
#  ('a', 'good'),
#  ('good', 'product.'),
#  ('product.', 'Will'),
#  ('Will', 'give'),
#  ('give', 'you'),
#  ('you', 'a'),
#  ('a', 'great'),
#  ('great', 'feeling.'),
#  ('I', 'really'),
#  ('really', 'enjoyed'),
#  ('enjoyed', 'using'),
#  ('using', 'this'),
#  ('this', 'product'),
#  ('product', 'with'),
#  ('with', 'my'),
#  ('my', 'husband.'),
#  ('husband.', 'After'),
#  ('After', '20+'),
#  ('20+', 'years'),
#  ('years', 'of'),
#  ('of', 'marriage,'),
#  ('marriage,', 'things'),
#  ('things', 'can'),
#  ('can', 'tend'),
#  ('tend', 'to'),
#  ('to', 'get'),
#  ('get', 'a'),
#  ('a', 'little'),
#  ('little', 'tired'),
#  ('tired', 'and'),
#  ('and', 'boring.'),
#  ('boring.', 'This'),
#  ('This', 'was'),
#  ('was', 'just'),
#  ('just', 'the'),
#  ('the', 'thing'),
#  ('thing', 'we'),
#  ('we', 'needed'),
#  ('needed', 'to'),
#  ('to', 'shake'),
#  ('shake', 'things'),
#  ('things', 'up'),
#  ('up', 'a'),
#  ('a', 'bit.'),
#  ('bit.', 'The'),
#  ('The', 'packaging'),
#  ('packaging', 'and'),
#  ('and', 'pump'),
#  ('pump', 'dispenser'),
#  ('dispenser', 'is'),
#  ('is', 'awesome.'),
#  ('awesome.', 'The'),
#  ('The', 'product'),
#  ('product', 'itself'),
#  ('itself', 'does'),
#  ('does', 'not'),
#  ('not', 'disappoint.'),
#  ('disappoint.', 'A'),
#  ('A', 'little'),
#  ('little', 'goes'),
#  ('goes', 'a'),
#  ('a', 'very'),
#  ('very', 'long'),
#  ('long', 'way.'),
#  ('way.', 'It'),
#  ('It', 'provides'),
#  ('provides', 'a'),
#  ('a', 'slight'),
#  ('slight', 'warming'),
#  ('warming', 'sensation'),
#  ('sensation', 'when'),
#  ('when', 'in'),
#  ('in', 'use'),
#  ('use', 'and'),
#  ('and', 'does'),
#  ('does', 'not'),
#  ('not', 'become'),
#  ('become', 'sticky'),
#  ('sticky', 'or'),
#  ('or', 'tacky'),
#  ('tacky', 'in'),
#  ('in', 'anyway.'),
#  ('anyway.', 'This'),
#  ('This', 'is'),
#  ('is', 'an'),
#  ('an', 'excellent'),
#  ('excellent', 'choice'),
#  ('choice', 'for'),
#  ('for', 'an'),
#  ('an', 'intimate'),
#  ('intimate', 'lubricant.'),
#  ('lubricant.', 'I'),
#  ('I', 'received'),
#  ('received', 'a'),
#  ('a', 'free'),
#  ('free', 'product'),
#  ('product', 'for'),
#  ('for', 'the'),
#  ('the', 'purpose'),
#  ('purpose', 'of'),
#  ('of', 'my'),
#  ('my', 'review.'),
#  ('review.', 'Opinions'),
#  ('Opinions', 'are'),
#  ('are', '100'),
#  ('100', 'my'),
#  ('my', 'own.'),
#  ('Awesome', 'Product'),
#  ('Product', 'for'),
#  ('for', 'couples.'),
#  ('couples.', 'It'),
#  ('It', 'is'),
#  ('is', 'a'),
#  ('a', 'warm'),
#  ('warm', 'feeling'),
#  ('feeling', 'lubricant'),
#  ...]

# %%
n3_gram
# Out:
# [('i', 'love', 'this'),
#  ('love', 'this', 'album.'),
#  ('this', 'album.', "it's"),
#  ('album.', "it's", 'very'),
#  ("it's", 'very', 'good.'),
#  ('very', 'good.', 'more'),
#  ('good.', 'more', 'to'),
#  ('more', 'to', 'the'),
#  ('to', 'the', 'hip'),
#  ('the', 'hip', 'hop'),
#  ('hip', 'hop', 'side'),
#  ('hop', 'side', 'than'),
#  ('side', 'than', 'her'),
#  ('than', 'her', 'current'),
#  ('her', 'current', 'pop'),
#  ('current', 'pop', 'sound..'),
#  ('pop', 'sound..', 'SO'),
#  ('sound..', 'SO', 'HYPE!'),
#  ('SO', 'HYPE!', 'i'),
#  ('HYPE!', 'i', 'listen'),
#  ('i', 'listen', 'to'),
#  ('listen', 'to', 'this'),
#  ('to', 'this', 'everyday'),
#  ('this', 'everyday', 'at'),
#  ('everyday', 'at', 'the'),
#  ('at', 'the', 'gym!'),
#  ('the', 'gym!', 'i'),
#  ('gym!', 'i', 'give'),
#  ('i', 'give', 'it'),
#  ('give', 'it', '5star'),
#  ('it', '5star', 'rating'),
#  ('5star', 'rating', 'all'),
#  ('rating', 'all', 'the'),
#  ('all', 'the', 'way.'),
#  ('the', 'way.', 'her'),
#  ('way.', 'her', 'metaphors'),
#  ('her', 'metaphors', 'are'),
#  ('metaphors', 'are', 'just'),
#  ('are', 'just', 'crazy.'),
#  ('Good', 'flavor.', 'This'),
#  ('flavor.', 'This', 'review'),
#  ('This', 'review', 'was'),
#  ('review', 'was', 'collected'),
#  ('was', 'collected', 'as'),
#  ('collected', 'as', 'part'),
#  ('as', 'part', 'of'),
#  ('part', 'of', 'a'),
#  ('of', 'a', 'promotion.'),
#  ('I', 'read', 'through'),
#  ('read', 'through', 'the'),
#  ('through', 'the', 'reviews'),
#  ('the', 'reviews', 'on'),
#  ('reviews', 'on', 'here'),
#  ('on', 'here', 'before'),
#  ('here', 'before', 'looking'),
#  ('before', 'looking', 'in'),
#  ('looking', 'in', 'to'),
#  ('in', 'to', 'buying'),
#  ('to', 'buying', 'one'),
#  ('buying', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'couples'),
#  ('the', 'couples', 'lubricants,'),
#  ('couples', 'lubricants,', 'and'),
#  ('lubricants,', 'and', 'was'),
#  ('and', 'was', 'ultimately'),
#  ('was', 'ultimately', 'disappointed'),
#  ('ultimately', 'disappointed', 'that'),
#  ('disappointed', 'that', 'it'),
#  ('that', 'it', "didn't"),
#  ('it', "didn't", 'even'),
#  ("didn't", 'even', 'live'),
#  ('even', 'live', 'up'),
#  ('live', 'up', 'to'),
#  ('up', 'to', 'the'),
#  ('to', 'the', 'reviews'),
#  ('the', 'reviews', 'I'),
#  ('reviews', 'I', 'had'),
#  ('I', 'had', 'read.'),
#  ('had', 'read.', 'For'),
#  ('read.', 'For', 'starters,'),
#  ('For', 'starters,', 'neither'),
#  ('starters,', 'neither', 'my'),
#  ('neither', 'my', 'boyfriend'),
#  ('my', 'boyfriend', 'nor'),
#  ('boyfriend', 'nor', 'I'),
#  ('nor', 'I', 'could'),
#  ('I', 'could', 'notice'),
#  ('could', 'notice', 'any'),
#  ('notice', 'any', 'sort'),
#  ('any', 'sort', 'of'),
#  ('sort', 'of', 'enhanced'),
#  ('of', 'enhanced', 'or'),
#  ('enhanced', 'or', "'captivating'"),
#  ('or', "'captivating'", 'sensation.'),
#  ("'captivating'", 'sensation.', 'What'),
#  ('sensation.', 'What', 'we'),
#  ('What', 'we', 'did'),
#  ('we', 'did', 'notice,'),
#  ('did', 'notice,', 'however,'),
#  ('notice,', 'however,', 'was'),
#  ('however,', 'was', 'the'),
#  ('was', 'the', 'messy'),
#  ('the', 'messy', 'consistency'),
#  ('messy', 'consistency', 'that'),
#  ('consistency', 'that', 'was'),
#  ('that', 'was', 'reminiscent'),
#  ('was', 'reminiscent', 'of'),
#  ('reminiscent', 'of', 'a'),
#  ('of', 'a', 'more'),
#  ('a', 'more', 'liquid-y'),
#  ('more', 'liquid-y', 'vaseline.'),
#  ('liquid-y', 'vaseline.', 'It'),
#  ('vaseline.', 'It', 'was'),
#  ('It', 'was', 'difficult'),
#  ('was', 'difficult', 'to'),
#  ('difficult', 'to', 'clean'),
#  ('to', 'clean', 'up,'),
#  ('clean', 'up,', 'and'),
#  ('up,', 'and', 'was'),
#  ('and', 'was', 'not'),
#  ('was', 'not', 'a'),
#  ('not', 'a', 'pleasant,'),
#  ('a', 'pleasant,', 'especially'),
#  ('pleasant,', 'especially', 'since'),
#  ('especially', 'since', 'it'),
#  ('since', 'it', 'lacked'),
#  ('it', 'lacked', 'the'),
#  ('lacked', 'the', "'captivating'"),
#  ('the', "'captivating'", 'sensation'),
#  ("'captivating'", 'sensation', 'we'),
#  ('sensation', 'we', 'had'),
#  ('we', 'had', 'both'),
#  ('had', 'both', 'been'),
#  ('both', 'been', 'expecting.'),
#  ('been', 'expecting.', "I'm"),
#  ('expecting.', "I'm", 'disappointed'),
#  ("I'm", 'disappointed', 'that'),
#  ('disappointed', 'that', 'I'),
#  ('that', 'I', 'paid'),
#  ('I', 'paid', 'as'),
#  ('paid', 'as', 'much'),
#  ('as', 'much', 'as'),
#  ('much', 'as', 'I'),
#  ('as', 'I', 'did'),
#  ('I', 'did', 'for'),
#  ('did', 'for', 'a'),
#  ('for', 'a', 'lube'),
#  ('a', 'lube', 'that'),
#  ('lube', 'that', 'I'),
#  ('that', 'I', "won't"),
#  ('I', "won't", 'use'),
#  ("won't", 'use', 'again,'),
#  ('use', 'again,', 'when'),
#  ('again,', 'when', 'I'),
#  ('when', 'I', 'could'),
#  ('I', 'could', 'just'),
#  ('could', 'just', 'use'),
#  ('just', 'use', 'their'),
#  ('use', 'their', 'normal'),
#  ('their', 'normal', 'personal'),
#  ('normal', 'personal', 'lubricant'),
#  ('personal', 'lubricant', 'for'),
#  ('lubricant', 'for', '1)'),
#  ('for', '1)', 'less'),
#  ('1)', 'less', 'money'),
#  ('less', 'money', 'and'),
#  ('money', 'and', '2)'),
#  ('and', '2)', 'less'),
#  ('2)', 'less', 'mess.'),
#  ('My', 'husband', 'bought'),
#  ('husband', 'bought', 'this'),
#  ('bought', 'this', 'gel'),
#  ('this', 'gel', 'for'),
#  ('gel', 'for', 'us.'),
#  ('for', 'us.', 'The'),
#  ('us.', 'The', 'gel'),
#  ('The', 'gel', 'caused'),
#  ('gel', 'caused', 'irritation'),
#  ('caused', 'irritation', 'and'),
#  ('irritation', 'and', 'it'),
#  ('and', 'it', 'felt'),
#  ('it', 'felt', 'like'),
#  ('felt', 'like', 'it'),
#  ('like', 'it', 'was'),
#  ('it', 'was', 'burning'),
#  ('was', 'burning', 'my'),
#  ('burning', 'my', 'skin.'),
#  ('my', 'skin.', 'I'),
#  ('skin.', 'I', "wouldn't"),
#  ('I', "wouldn't", 'recommend'),
#  ("wouldn't", 'recommend', 'this'),
#  ('recommend', 'this', 'gel.'),
#  ('My', 'boyfriend', 'and'),
#  ('boyfriend', 'and', 'I'),
#  ('and', 'I', 'bought'),
#  ('I', 'bought', 'this'),
#  ('bought', 'this', 'to'),
#  ('this', 'to', 'spice'),
#  ('to', 'spice', 'things'),
#  ('spice', 'things', 'up'),
#  ('things', 'up', 'in'),
#  ('up', 'in', 'the'),
#  ('in', 'the', 'bedroom'),
#  ('the', 'bedroom', 'and'),
#  ('bedroom', 'and', 'we'),
#  ('and', 'we', 'were'),
#  ('we', 'were', 'both'),
#  ('were', 'both', 'highly'),
#  ('both', 'highly', 'disappointed'),
#  ('highly', 'disappointed', 'in'),
#  ('disappointed', 'in', 'this'),
#  ('in', 'this', 'product.'),
#  ('this', 'product.', 'We'),
#  ('product.', 'We', 'bought'),
#  ('We', 'bought', 'this'),
#  ('bought', 'this', 'one'),
#  ('this', 'one', 'because'),
#  ('one', 'because', 'we'),
#  ('because', 'we', 'absolutely'),
#  ('we', 'absolutely', 'love'),
#  ('absolutely', 'love', 'the'),
#  ('love', 'the', 'ky'),
#  ('the', 'ky', 'yours'),
#  ('ky', 'yours', 'and'),
#  ('yours', 'and', 'mine'),
#  ('and', 'mine', 'and'),
#  ('mine', 'and', 'we'),
#  ('and', 'we', 'thought'),
#  ('we', 'thought', 'this'),
#  ('thought', 'this', 'would'),
#  ('this', 'would', 'have'),
#  ('would', 'have', 'a'),
#  ('have', 'a', 'similar'),
#  ('a', 'similar', 'affect'),
#  ('similar', 'affect', 'but'),
#  ('affect', 'but', 'it'),
#  ('but', 'it', 'did'),
#  ('it', 'did', 'absolutely'),
#  ('did', 'absolutely', 'nothing.'),
#  ('absolutely', 'nothing.', 'Do'),
#  ('nothing.', 'Do', 'not'),
#  ('Do', 'not', 'buy.'),
#  ('Bought', 'this', 'earlier'),
#  ('this', 'earlier', 'today'),
#  ('earlier', 'today', 'and'),
#  ('today', 'and', 'was'),
#  ('and', 'was', 'excited'),
#  ('was', 'excited', 'to'),
#  ('excited', 'to', 'check'),
#  ('to', 'check', 'it'),
#  ('check', 'it', 'out.'),
#  ('it', 'out.', 'Based'),
#  ('out.', 'Based', 'on'),
#  ('Based', 'on', 'the'),
#  ('on', 'the', 'product'),
#  ('the', 'product', 'description'),
#  ('product', 'description', 'I'),
#  ('description', 'I', 'was'),
#  ('I', 'was', 'expecting'),
#  ('was', 'expecting', 'something'),
#  ('expecting', 'something', 'but'),
#  ('something', 'but', 'it'),
#  ('but', 'it', 'was'),
#  ('it', 'was', 'just'),
#  ('was', 'just', 'like'),
#  ('just', 'like', 'the'),
#  ('like', 'the', 'regular'),
#  ('the', 'regular', 'KY.'),
#  ('regular', 'KY.', 'We'),
#  ('KY.', 'We', 'are'),
#  ('We', 'are', 'fans'),
#  ('are', 'fans', 'of'),
#  ('fans', 'of', 'the'),
#  ('of', 'the', 'his'),
#  ('the', 'his', 'and'),
#  ('his', 'and', 'hers'),
#  ('and', 'hers', 'so'),
#  ('hers', 'so', 'we'),
#  ('so', 'we', 'just'),
#  ('we', 'just', 'expected'),
#  ('just', 'expected', 'more'),
#  ('expected', 'more', 'and'),
#  ('more', 'and', 'were'),
#  ('and', 'were', 'left'),
#  ('were', 'left', 'a'),
#  ('left', 'a', 'little'),
#  ('a', 'little', 'disappointed.'),
#  ('I', 'bought', 'this'),
#  ('bought', 'this', 'product'),
#  ('this', 'product', 'for'),
#  ('product', 'for', 'my'),
#  ('for', 'my', 'husband'),
#  ('my', 'husband', 'and'),
#  ('husband', 'and', 'I'),
#  ('and', 'I', 'to'),
#  ('I', 'to', 'try'),
#  ('to', 'try', 'and'),
#  ('try', 'and', 'we'),
#  ('and', 'we', 'were'),
#  ('we', 'were', 'not'),
#  ('were', 'not', 'impressed'),
#  ('not', 'impressed', 'at'),
#  ('impressed', 'at', 'all.'),
#  ('at', 'all.', 'There'),
#  ('all.', 'There', 'was'),
#  ('There', 'was', 'no'),
#  ('was', 'no', 'tingling'),
#  ('no', 'tingling', 'or'),
#  ('tingling', 'or', 'warming.'),
#  ('or', 'warming.', 'It'),
#  ('warming.', 'It', 'left'),
#  ('It', 'left', 'us'),
#  ('left', 'us', 'both'),
#  ('us', 'both', 'very'),
#  ('both', 'very', 'sticky.'),
#  ('very', 'sticky.', 'I'),
#  ('sticky.', 'I', 'have'),
#  ('I', 'have', 'used'),
#  ('have', 'used', 'KY'),
#  ('used', 'KY', 'products'),
#  ('KY', 'products', 'in'),
#  ('products', 'in', 'the'),
#  ('in', 'the', 'past'),
#  ('the', 'past', '(loved'),
#  ('past', '(loved', 'KY'),
#  ('(loved', 'KY', 'his'),
#  ('KY', 'his', 'and'),
#  ('his', 'and', 'hers)'),
#  ('and', 'hers)', 'but'),
#  ('hers)', 'but', 'this'),
#  ('but', 'this', 'one'),
#  ('this', 'one', 'was'),
#  ('one', 'was', 'disappointing.'),
#  ('My', 'husband', 'and'),
#  ('husband', 'and', 'I'),
#  ('and', 'I', 'bought'),
#  ('I', 'bought', 'this'),
#  ('bought', 'this', 'for'),
#  ('this', 'for', 'some'),
#  ('for', 'some', 'extra'),
#  ('some', 'extra', 'fun.'),
#  ('extra', 'fun.', 'We'),
#  ('fun.', 'We', 'werevboth'),
#  ('We', 'werevboth', 'extremely'),
#  ('werevboth', 'extremely', 'disappointed.'),
#  ('extremely', 'disappointed.', 'Especially'),
#  ('disappointed.', 'Especially', 'for'),
#  ('Especially', 'for', 'the'),
#  ('for', 'the', 'price!'),
#  ('the', 'price!', 'Do'),
#  ('price!', 'Do', 'not'),
#  ('Do', 'not', 'waste'),
#  ('not', 'waste', 'your'),
#  ('waste', 'your', 'money'),
#  ('your', 'money', 'on'),
#  ('money', 'on', 'this'),
#  ('on', 'this', 'product.'),
#  ('this', 'product.', 'We'),
#  ('product.', 'We', 'felt'),
#  ('We', 'felt', 'nothing'),
#  ('felt', 'nothing', 'but'),
#  ('nothing', 'but', 'a'),
#  ('but', 'a', 'sticky'),
#  ('a', 'sticky', 'mess'),
#  ('sticky', 'mess', 'from'),
#  ('mess', 'from', 'it.'),
#  ('Got', 'as', 'a'),
#  ('as', 'a', 'surprise'),
#  ('a', 'surprise', 'for'),
#  ('surprise', 'for', 'my'),
#  ('for', 'my', 'husband'),
#  ('my', 'husband', 'there'),
#  ('husband', 'there', 'is'),
#  ('there', 'is', 'nothing'),
#  ('is', 'nothing', 'special'),
#  ('nothing', 'special', 'about'),
#  ('special', 'about', 'it'),
#  ('about', 'it', 'just'),
#  ('it', 'just', 'a'),
#  ('just', 'a', 'lube'),
#  ('a', 'lube', 'save'),
#  ('lube', 'save', 'the'),
#  ('save', 'the', 'money'),
#  ('the', 'money', 'and'),
#  ('money', 'and', 'get'),
#  ('and', 'get', 'plain'),
#  ('get', 'plain', 'KY'),
#  ('plain', 'KY', 'if'),
#  ('KY', 'if', 'you'),
#  ('if', 'you', 'just'),
#  ('you', 'just', 'need'),
#  ('just', 'need', 'a'),
#  ('need', 'a', 'lube'),
#  ('a', 'lube', 'wish'),
#  ('lube', 'wish', 'I'),
#  ('wish', 'I', 'could'),
#  ('I', 'could', 'return'),
#  ('could', 'return', 'it'),
#  ('return', 'it', 'for'),
#  ('it', 'for', 'a'),
#  ('for', 'a', 'refund'),
#  ('tried', 'it', 'with'),
#  ('it', 'with', 'my'),
#  ('with', 'my', 'husband'),
#  ('my', 'husband', 'and'),
#  ('husband', 'and', 'felt'),
#  ('and', 'felt', 'no'),
#  ('felt', 'no', 'different'),
#  ('no', 'different', 'there'),
#  ('different', 'there', 'was'),
#  ('there', 'was', 'no'),
#  ('was', 'no', 'effect'),
#  ('no', 'effect', 'no'),
#  ('effect', 'no', 'change'),
#  ('no', 'change', 'first'),
#  ('change', 'first', 'te'),
#  ('first', 'te', 'using'),
#  ('te', 'using', 'ky'),
#  ('using', 'ky', 'gel'),
#  ('ky', 'gel', 'not'),
#  ('gel', 'not', 'sure'),
#  ('not', 'sure', 'if'),
#  ('sure', 'if', 'i'),
#  ('if', 'i', 'want'),
#  ('i', 'want', 'to'),
#  ('want', 'to', 'try'),
#  ('to', 'try', 'any'),
#  ('try', 'any', 'others...'),
#  ('Purchased', 'this', 'thinking'),
#  ('this', 'thinking', 'it'),
#  ('thinking', 'it', 'would'),
#  ('it', 'would', 'have'),
#  ('would', 'have', 'some'),
#  ('have', 'some', 'sort'),
#  ('some', 'sort', 'of'),
#  ('sort', 'of', 'warming'),
#  ('of', 'warming', 'effect'),
#  ('warming', 'effect', 'but'),
#  ('effect', 'but', "it's"),
#  ('but', "it's", 'the'),
#  ("it's", 'the', 'same'),
#  ('the', 'same', 'as'),
#  ('same', 'as', 'the'),
#  ('as', 'the', 'original.'),
#  ('the', 'original.', "Don't"),
#  ('original.', "Don't", 'waste'),
#  ("Don't", 'waste', 'your'),
#  ('waste', 'your', 'money.'),
#  ('Bought', 'this', 'to'),
#  ('this', 'to', 'enhance'),
#  ('to', 'enhance', 'our'),
#  ('enhance', 'our', 'time'),
#  ('our', 'time', 'a'),
#  ('time', 'a', 'bit,'),
#  ('a', 'bit,', 'did'),
#  ('bit,', 'did', 'abslutely'),
#  ('did', 'abslutely', 'nothing'),
#  ('abslutely', 'nothing', 'very'),
#  ('nothing', 'very', 'disappointed'),
#  ('very', 'disappointed', 'especially'),
#  ('disappointed', 'especially', 'because'),
#  ('especially', 'because', 'its'),
#  ('because', 'its', 'almost'),
#  ('its', 'almost', '20!'),
#  ('I', 'bought', 'this'),
#  ('bought', 'this', 'after'),
#  ('this', 'after', 'really'),
#  ('after', 'really', 'liking'),
#  ('really', 'liking', 'the'),
#  ('liking', 'the', 'his'),
#  ('the', 'his', 'n'),
#  ('his', 'n', 'hers'),
#  ('n', 'hers', 'variety'),
#  ('hers', 'variety', 'but'),
#  ('variety', 'but', 'this'),
#  ('but', 'this', 'is'),
#  ('this', 'is', 'nothing'),
#  ('is', 'nothing', 'like'),
#  ('nothing', 'like', 'that'),
#  ('like', 'that', 'very'),
#  ('that', 'very', 'disappointed'),
#  ('very', 'disappointed', 'with'),
#  ('disappointed', 'with', 'this'),
#  ('with', 'this', 'product.'),
#  ('First', 'time', 'purchase'),
#  ('time', 'purchase', 'of'),
#  ('purchase', 'of', 'this'),
#  ('of', 'this', 'type'),
#  ('this', 'type', 'of'),
#  ('type', 'of', 'product.'),
#  ('of', 'product.', 'Maybe'),
#  ('product.', 'Maybe', 'I'),
#  ('Maybe', 'I', 'expected'),
#  ('I', 'expected', 'too'),
#  ('expected', 'too', 'much.'),
#  ('too', 'much.', 'Did'),
#  ('much.', 'Did', 'not'),
#  ('Did', 'not', 'think'),
#  ('not', 'think', 'there'),
#  ('think', 'there', 'was'),
#  ('there', 'was', 'any'),
#  ('was', 'any', 'warming'),
#  ('any', 'warming', 'feeling'),
#  ('warming', 'feeling', 'at'),
#  ('feeling', 'at', 'all.'),
#  ('at', 'all.', 'Left'),
#  ('all.', 'Left', 'us'),
#  ('Left', 'us', 'sticky!'),
#  ('us', 'sticky!', 'Even'),
#  ('sticky!', 'Even', 'after'),
#  ('Even', 'after', 'trying'),
#  ('after', 'trying', 'to'),
#  ('trying', 'to', 'was'),
#  ('to', 'was', 'it'),
#  ('was', 'it', 'off.'),
#  ('I', 'bought', 'this'),
#  ('bought', 'this', 'and'),
#  ('this', 'and', 'tried'),
#  ('and', 'tried', 'this'),
#  ('tried', 'this', 'with'),
#  ('this', 'with', 'my'),
#  ('with', 'my', 'wife'),
#  ('my', 'wife', 'but'),
#  ('wife', 'but', 'we'),
#  ('but', 'we', 'did'),
#  ('we', 'did', 'not'),
#  ('did', 'not', 'enjoy'),
#  ('not', 'enjoy', 'it'),
#  ('enjoy', 'it', '..we'),
#  ('it', '..we', 'did'),
#  ('..we', 'did', 'not'),
#  ('did', 'not', 'feel'),
#  ('not', 'feel', 'anything'),
#  ('feel', 'anything', 'enhancement'),
#  ('anything', 'enhancement', 'with'),
#  ('enhancement', 'with', 'this'),
#  ('with', 'this', 'product'),
#  ('this', 'product', 'at'),
#  ('product', 'at', 'all'),
#  ('at', 'all', 'such'),
#  ('all', 'such', 'as'),
#  ('such', 'as', 'the'),
#  ('as', 'the', 'his-her'),
#  ('the', 'his-her', 'product.'),
#  ('I', 'bought', 'this'),
#  ('bought', 'this', 'product'),
#  ('this', 'product', 'to'),
#  ('product', 'to', 'spice'),
#  ('to', 'spice', 'things'),
#  ('spice', 'things', 'up'),
#  ('things', 'up', 'with'),
#  ('up', 'with', 'my'),
#  ('with', 'my', 'fianc'),
#  ('my', 'fianc', 'and'),
#  ('fianc', 'and', 'it'),
#  ('and', 'it', "didn't"),
#  ('it', "didn't", 'do'),
#  ("didn't", 'do', 'anything!'),
#  ('do', 'anything!', 'No'),
#  ('anything!', 'No', 'passion.'),
#  ('No', 'passion.', 'Will'),
#  ('passion.', 'Will', 'not'),
#  ('Will', 'not', 'buy'),
#  ('not', 'buy', 'again'),
#  ('I', 'bought', 'this'),
#  ('bought', 'this', 'to'),
#  ('this', 'to', 'try'),
#  ('to', 'try', 'to'),
#  ('try', 'to', 'spice'),
#  ('to', 'spice', 'things'),
#  ('spice', 'things', 'up,'),
#  ('things', 'up,', 'but'),
#  ('up,', 'but', 'I'),
#  ('but', 'I', 'felt'),
#  ('I', 'felt', 'nothing.'),
#  ('felt', 'nothing.', 'Very'),
#  ('nothing.', 'Very', 'disappointing'),
#  ('Very', 'disappointing', 'to'),
#  ('disappointing', 'to', 'be'),
#  ('to', 'be', 'honest.'),
#  ('I', 'bought', 'this'),
#  ('bought', 'this', 'because'),
#  ('this', 'because', 'it'),
#  ('because', 'it', 'had'),
#  ('it', 'had', 'better'),
#  ('had', 'better', 'reviews'),
#  ('better', 'reviews', 'than'),
#  ('reviews', 'than', 'the'),
#  ('than', 'the', 'his'),
#  ('the', 'his', 'and'),
#  ('his', 'and', 'hers'),
#  ('and', 'hers', 'jelly,'),
#  ('hers', 'jelly,', 'but'),
#  ('jelly,', 'but', 'I'),
#  ('but', 'I', 'feel'),
#  ('I', 'feel', 'like'),
#  ('feel', 'like', 'it'),
#  ('like', 'it', "didn't"),
#  ('it', "didn't", 'work'),
#  ("didn't", 'work', 'that'),
#  ('work', 'that', 'well'),
#  ('that', 'well', 'for'),
#  ('well', 'for', 'us.'),
#  ('for', 'us.', 'It'),
#  ('us.', 'It', 'was'),
#  ('It', 'was', 'kind'),
#  ('was', 'kind', 'of'),
#  ('kind', 'of', 'warm-feeling,'),
#  ('of', 'warm-feeling,', 'but'),
#  ('warm-feeling,', 'but', "that's"),
#  ('but', "that's", 'about'),
#  ("that's", 'about', 'it.'),
#  ('about', 'it.', 'I'),
#  ('it.', 'I', 'guess'),
#  ('I', 'guess', 'I'),
#  ('guess', 'I', "don't"),
#  ('I', "don't", 'know'),
#  ("don't", 'know', "what's"),
#  ('know', "what's", 'supposed'),
#  ("what's", 'supposed', 'to'),
#  ('supposed', 'to', 'happen!'),
#  ('to', 'happen!', 'Lol'),
#  ('It', 'was', 'my'),
#  ('was', 'my', 'first'),
#  ('my', 'first', 'time'),
#  ('first', 'time', 'using'),
#  ('time', 'using', 'k-y.'),
#  ('using', 'k-y.', 'It'),
#  ('k-y.', 'It', "didn't"),
#  ('It', "didn't", 'do'),
#  ("didn't", 'do', 'anything'),
#  ('do', 'anything', 'in'),
#  ('anything', 'in', 'my'),
#  ('in', 'my', 'opinion'),
#  ('my', 'opinion', 'it'),
#  ('opinion', 'it', 'felt'),
#  ('it', 'felt', 'like'),
#  ('felt', 'like', 'every'),
#  ('like', 'every', 'time'),
#  ('every', 'time', 'we'),
#  ('time', 'we', 'did'),
#  ('we', 'did', 'anything.'),
#  ('did', 'anything.', 'Then'),
#  ('anything.', 'Then', 'again'),
#  ('Then', 'again', 'was'),
#  ('again', 'was', 'my'),
#  ('was', 'my', 'first'),
#  ('my', 'first', 'time'),
#  ('first', 'time', 'so'),
#  ('time', 'so', 'probably'),
#  ('so', 'probably', 'did'),
#  ('probably', 'did', 'Somthing'),
#  ('did', 'Somthing', 'wrong.'),
#  ('I', 'noticed', 'this'),
#  ('noticed', 'this', 'product'),
#  ('this', 'product', 'on'),
#  ('product', 'on', 'clearance'),
#  ('on', 'clearance', 'at'),
#  ('clearance', 'at', 'a'),
#  ('at', 'a', 'store'),
#  ('a', 'store', 'I'),
#  ('store', 'I', 'shop'),
#  ('I', 'shop', 'frequently'),
#  ('shop', 'frequently', 'and'),
#  ('frequently', 'and', 'decided'),
#  ('and', 'decided', 'to'),
#  ('decided', 'to', 'give'),
#  ('to', 'give', 'it'),
#  ('give', 'it', 'a'),
#  ('it', 'a', 'try.'),
#  ('a', 'try.', 'My'),
#  ('try.', 'My', 'husband'),
#  ('My', 'husband', 'and'),
#  ('husband', 'and', 'I'),
#  ('and', 'I', 'LOVE'),
#  ('I', 'LOVE', 'it!'),
#  ('LOVE', 'it!', 'We'),
#  ('it!', 'We', 'went'),
#  ('We', 'went', 'back'),
#  ('went', 'back', 'and'),
#  ('back', 'and', 'bought'),
#  ('and', 'bought', 'every'),
#  ('bought', 'every', 'box'),
#  ('every', 'box', 'left!'),
#  ('box', 'left!', 'I,'),
#  ('left!', 'I,', 'like'),
#  ('I,', 'like', 'others'),
#  ('like', 'others', 'have'),
#  ('others', 'have', 'mentioned,'),
#  ('have', 'mentioned,', 'am'),
#  ('mentioned,', 'am', 'not'),
#  ('am', 'not', 'sure'),
#  ('not', 'sure', 'what'),
#  ('sure', 'what', 'it'),
#  ('what', 'it', 'is'),
#  ('it', 'is', 'supposed'),
#  ('is', 'supposed', 'to'),
#  ('supposed', 'to', 'do'),
#  ('to', 'do', 'other'),
#  ('do', 'other', 'than'),
#  ('other', 'than', 'be'),
#  ('than', 'be', 'a'),
#  ('be', 'a', 'lubricant'),
#  ('a', 'lubricant', 'but'),
#  ('lubricant', 'but', 'for'),
#  ('but', 'for', 'that'),
#  ('for', 'that', 'purpose'),
#  ('that', 'purpose', 'we'),
#  ('purpose', 'we', 'like'),
#  ('we', 'like', 'it'),
#  ('like', 'it', 'much'),
#  ('it', 'much', 'better'),
#  ('much', 'better', 'than'),
#  ('better', 'than', 'regular'),
#  ('than', 'regular', 'KY'),
#  ('regular', 'KY', 'Jelly'),
#  ('KY', 'Jelly', '(which'),
#  ('Jelly', '(which', 'tends'),
#  ('(which', 'tends', 'to'),
#  ('tends', 'to', 'dry'),
#  ('to', 'dry', 'out'),
#  ('dry', 'out', 'and'),
#  ('out', 'and', 'disappear'),
#  ('and', 'disappear', 'for'),
#  ('disappear', 'for', 'us).'),
#  ('for', 'us).', 'This'),
#  ('us).', 'This', 'product'),
#  ('This', 'product', 'stays'),
#  ('product', 'stays', 'on'),
#  ('stays', 'on', 'for'),
#  ('on', 'for', 'awhile'),
#  ('for', 'awhile', 'and'),
#  ('awhile', 'and', 'makes'),
#  ('and', 'makes', 'for'),
#  ('makes', 'for', 'a'),
#  ('for', 'a', 'very'),
#  ('a', 'very', 'pleasurable'),
#  ('very', 'pleasurable', 'experience.'),
#  ('pleasurable', 'experience.', 'The'),
#  ('experience.', 'The', 'only'),
#  ('The', 'only', 'drawback'),
#  ('only', 'drawback', 'is'),
#  ('drawback', 'is', 'that'),
#  ('is', 'that', 'we'),
#  ('that', 'we', 'find'),
#  ('we', 'find', 'it'),
#  ('find', 'it', 'to'),
#  ('it', 'to', 'be'),
#  ('to', 'be', 'a'),
#  ('be', 'a', 'bit'),
#  ('a', 'bit', 'sticky.'),
#  ('bit', 'sticky.', 'After'),
#  ('sticky.', 'After', 'applying'),
#  ('After', 'applying', 'it'),
#  ('applying', 'it', 'with'),
#  ('it', 'with', 'your'),
#  ('with', 'your', 'hands'),
#  ('your', 'hands', "you're"),
#  ('hands', "you're", 'left'),
#  ("you're", 'left', 'with'),
#  ('left', 'with', 'a'),
#  ('with', 'a', 'sticky'),
#  ('a', 'sticky', 'hand'),
#  ('sticky', 'hand', 'and'),
#  ('hand', 'and', 'I'),
#  ('and', 'I', 'agree'),
#  ('I', 'agree', 'a'),
#  ('agree', 'a', 'little'),
#  ('a', 'little', 'goes'),
#  ('little', 'goes', 'a'),
#  ('goes', 'a', 'long'),
#  ('a', 'long', 'way!'),
#  ('long', 'way!', 'I'),
#  ('way!', 'I', 'personally'),
#  ('I', 'personally', 'have'),
#  ('personally', 'have', 'to'),
#  ('have', 'to', 'be'),
#  ('to', 'be', 'very'),
#  ('be', 'very', 'careful'),
#  ('very', 'careful', 'with'),
#  ('careful', 'with', 'all'),
#  ('with', 'all', 'products'),
#  ('all', 'products', 'due'),
#  ('products', 'due', 'to'),
#  ('due', 'to', 'skin'),
#  ('to', 'skin', 'irritation'),
#  ('skin', 'irritation', 'and'),
#  ('irritation', 'and', 'surprisingly'),
#  ('and', 'surprisingly', 'this'),
#  ('surprisingly', 'this', 'actually'),
#  ('this', 'actually', 'seems'),
#  ('actually', 'seems', 'to'),
#  ('seems', 'to', 'help'),
#  ('to', 'help', 'that.'),
#  ('help', 'that.', 'I'),
#  ('that.', 'I', 'did'),
#  ('I', 'did', 'NOT'),
#  ('did', 'NOT', 'receive'),
#  ('NOT', 'receive', 'a'),
#  ('receive', 'a', 'sample'),
#  ('a', 'sample', 'and'),
#  ('sample', 'and', 'never'),
#  ('and', 'never', 'have.'),
#  ('I', 'used', 'this'),
#  ('used', 'this', 'product'),
#  ('this', 'product', 'a'),
#  ('product', 'a', 'couple'),
#  ('a', 'couple', 'of'),
#  ('couple', 'of', 'times'),
#  ('of', 'times', 'since'),
#  ('times', 'since', 'i'),
#  ('since', 'i', 'recived'),
#  ('i', 'recived', 'it'),
#  ('recived', 'it', 'free'),
#  ('it', 'free', 'to'),
#  ('free', 'to', 'try'),
#  ('to', 'try', 'and'),
#  ('try', 'and', 'it'),
#  ('and', 'it', 'has'),
#  ('it', 'has', 'been'),
#  ('has', 'been', 'a'),
#  ('been', 'a', 'good'),
#  ('a', 'good', 'experiance'),
#  ('good', 'experiance', 'it'),
#  ('experiance', 'it', 'feel'),
#  ('it', 'feel', 'warm'),
#  ('feel', 'warm', 'so'),
#  ('warm', 'so', 'its'),
#  ('so', 'its', 'a'),
#  ('its', 'a', 'pretty'),
#  ('a', 'pretty', 'good'),
#  ('pretty', 'good', 'sensation'),
#  ('good', 'sensation', 'so'),
#  ('sensation', 'so', 'i'),
#  ('so', 'i', 'recomend.'),
#  ('Used', 'a', 'few'),
#  ('a', 'few', 'times'),
#  ('few', 'times', 'stays'),
#  ('times', 'stays', 'a'),
#  ('stays', 'a', 'bit'),
#  ('a', 'bit', 'sticky'),
#  ('bit', 'sticky', 'but'),
#  ('sticky', 'but', 'not'),
#  ('but', 'not', 'too'),
#  ('not', 'too', 'bad,'),
#  ('too', 'bad,', 'better'),
#  ('bad,', 'better', 'than'),
#  ('better', 'than', 'most'),
#  ('than', 'most', 'products'),
#  ('Loved', 'This', 'review'),
#  ('This', 'review', 'was'),
#  ('review', 'was', 'collected'),
#  ('was', 'collected', 'as'),
#  ('collected', 'as', 'part'),
#  ('as', 'part', 'of'),
#  ('part', 'of', 'a'),
#  ('of', 'a', 'promotion.'),
#  ('This', 'is', 'a'),
#  ('is', 'a', 'good'),
#  ('a', 'good', 'product.'),
#  ('good', 'product.', 'Will'),
#  ('product.', 'Will', 'give'),
#  ('Will', 'give', 'you'),
#  ('give', 'you', 'a'),
#  ('you', 'a', 'great'),
#  ('a', 'great', 'feeling.'),
#  ('I', 'really', 'enjoyed'),
#  ('really', 'enjoyed', 'using'),
#  ('enjoyed', 'using', 'this'),
#  ('using', 'this', 'product'),
#  ('this', 'product', 'with'),
#  ('product', 'with', 'my'),
#  ('with', 'my', 'husband.'),
#  ('my', 'husband.', 'After'),
#  ('husband.', 'After', '20+'),
#  ('After', '20+', 'years'),
#  ('20+', 'years', 'of'),
#  ('years', 'of', 'marriage,'),
#  ('of', 'marriage,', 'things'),
#  ('marriage,', 'things', 'can'),
#  ('things', 'can', 'tend'),
#  ('can', 'tend', 'to'),
#  ('tend', 'to', 'get'),
#  ('to', 'get', 'a'),
#  ('get', 'a', 'little'),
#  ('a', 'little', 'tired'),
#  ('little', 'tired', 'and'),
#  ('tired', 'and', 'boring.'),
#  ('and', 'boring.', 'This'),
#  ('boring.', 'This', 'was'),
#  ('This', 'was', 'just'),
#  ('was', 'just', 'the'),
#  ('just', 'the', 'thing'),
#  ('the', 'thing', 'we'),
#  ('thing', 'we', 'needed'),
#  ('we', 'needed', 'to'),
#  ('needed', 'to', 'shake'),
#  ('to', 'shake', 'things'),
#  ('shake', 'things', 'up'),
#  ('things', 'up', 'a'),
#  ('up', 'a', 'bit.'),
#  ('a', 'bit.', 'The'),
#  ('bit.', 'The', 'packaging'),
#  ('The', 'packaging', 'and'),
#  ('packaging', 'and', 'pump'),
#  ('and', 'pump', 'dispenser'),
#  ('pump', 'dispenser', 'is'),
#  ('dispenser', 'is', 'awesome.'),
#  ('is', 'awesome.', 'The'),
#  ('awesome.', 'The', 'product'),
#  ('The', 'product', 'itself'),
#  ('product', 'itself', 'does'),
#  ('itself', 'does', 'not'),
#  ('does', 'not', 'disappoint.'),
#  ('not', 'disappoint.', 'A'),
#  ('disappoint.', 'A', 'little'),
#  ('A', 'little', 'goes'),
#  ('little', 'goes', 'a'),
#  ('goes', 'a', 'very'),
#  ('a', 'very', 'long'),
#  ('very', 'long', 'way.'),
#  ('long', 'way.', 'It'),
#  ('way.', 'It', 'provides'),
#  ('It', 'provides', 'a'),
#  ('provides', 'a', 'slight'),
#  ('a', 'slight', 'warming'),
#  ('slight', 'warming', 'sensation'),
#  ('warming', 'sensation', 'when'),
#  ('sensation', 'when', 'in'),
#  ('when', 'in', 'use'),
#  ('in', 'use', 'and'),
#  ('use', 'and', 'does'),
#  ('and', 'does', 'not'),
#  ('does', 'not', 'become'),
#  ('not', 'become', 'sticky'),
#  ('become', 'sticky', 'or'),
#  ('sticky', 'or', 'tacky'),
#  ('or', 'tacky', 'in'),
#  ('tacky', 'in', 'anyway.'),
#  ('in', 'anyway.', 'This'),
#  ('anyway.', 'This', 'is'),
#  ('This', 'is', 'an'),
#  ('is', 'an', 'excellent'),
#  ('an', 'excellent', 'choice'),
#  ('excellent', 'choice', 'for'),
#  ('choice', 'for', 'an'),
#  ('for', 'an', 'intimate'),
#  ('an', 'intimate', 'lubricant.'),
#  ('intimate', 'lubricant.', 'I'),
#  ('lubricant.', 'I', 'received'),
#  ('I', 'received', 'a'),
#  ('received', 'a', 'free'),
#  ('a', 'free', 'product'),
#  ('free', 'product', 'for'),
#  ('product', 'for', 'the'),
#  ('for', 'the', 'purpose'),
#  ('the', 'purpose', 'of'),
#  ('purpose', 'of', 'my'),
#  ('of', 'my', 'review.'),
#  ('my', 'review.', 'Opinions'),
#  ('review.', 'Opinions', 'are'),
#  ('Opinions', 'are', '100'),
#  ('are', '100', 'my'),
#  ('100', 'my', 'own.'),
#  ('Awesome', 'Product', 'for'),
#  ('Product', 'for', 'couples.'),
#  ('for', 'couples.', 'It'),
#  ('couples.', 'It', 'is'),
#  ('It', 'is', 'a'),
#  ('is', 'a', 'warm'),
#  ('a', 'warm', 'feeling'),
#  ('warm', 'feeling', 'lubricant'),
#  ('feeling', 'lubricant', 'and'),
#  ('lubricant', 'and', 'not'),
#  ('and', 'not', 'sticky'),
#  ('not', 'sticky', 'like'),
#  ('sticky', 'like', 'a'),
#  ('like', 'a', 'lot'),
#  ('a', 'lot', 'of'),
#  ('lot', 'of', 'other'),
#  ('of', 'other', 'lubricants.It'),
#  ('other', 'lubricants.It', 'is'),
#  ('lubricants.It', 'is', 'very'),
#  ('is', 'very', 'easy'),
#  ('very', 'easy', 'to'),
#  ('easy', 'to', 'clean'),
#  ('to', 'clean', 'up'),
#  ('clean', 'up', 'after'),
#  ('up', 'after', 'use.I'),
#  ('after', 'use.I', 'will'),
#  ('use.I', 'will', 'absolutely'),
#  ('will', 'absolutely', 'be'),
#  ('absolutely', 'be', 'purchasing'),
#  ('be', 'purchasing', 'more'),
#  ('purchasing', 'more', 'in'),
#  ('more', 'in', 'the'),
#  ('in', 'the', 'future.'),
#  ('the', 'future.', 'I'),
#  ('future.', 'I', 'received'),
#  ...]
